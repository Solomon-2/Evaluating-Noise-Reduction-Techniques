# %%
# Cell 1: Imports and Configuration
print("--- Setting up MULTI-EDF threading-based feature extraction (16kHz) ---")

import os
import time
import numpy as np
import pandas as pd
import librosa
import mne
from concurrent.futures import ThreadPoolExecutor, as_completed
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Add your custom XML parser
import sys
sys.path.append('../src')

# Test import first
try:
    from working_with_xml import extract_apnea_events
    print("✅ XML parser imported successfully")
except Exception as e:
    print(f"❌ XML parser import failed: {e}")

# Configuration - Multi-EDF processing
PATIENT_DATA_DIR = "F:/Solo All In One Docs/Evaluating-Noise-Reduction-Techniques/data/sleep_data"
OUTPUT_FILE = "../data/datasets/final_local_dataset.csv" # New filename for 16kHz dataset
PATIENTS_TO_PROCESS = ['patient_01', 'patient_02', 'patient_03', 'patient_04', 'patient_05', 'patient_06','patient_07',
                       'patient_07','patient_08','patient_09','patient_10','patient_11','patient_12','patient_13','patient_14','patient_15'
                       ,'patient_16','patient_17','patient_18','patient_19','patient_20','patient_21','patient_22','patient_23','patient_24']
MAX_WORKERS = 4  # Keep at 4 for memory safety with multiple EDFs

# Audio processing settings
AUDIO_CHANNEL = 'Mic'
FRAME_DURATION = 30.0  # seconds
OVERLAP_RATIO = 0.5
APNEA_THRESHOLD = 0.1

print(f"✅ Configuration set for {len(PATIENTS_TO_PROCESS)} patients with {MAX_WORKERS} threads")
print(f"📁 Data directory: {PATIENT_DATA_DIR}")
print(f"📊 Output file: {OUTPUT_FILE}")
print(f"🎯 Processing: ALL EDF files per patient (5 EDFs × 6 patients = 30 hours)")
print(f"🧵 Memory-safe: Sequential EDF processing within each patient")
print(f"⚡ Threading: Between patients (4 concurrent patients)")
print(f"🎵 Audio: Downsampling to 16kHz for optimized processing")
# Out:
# --- Setting up MULTI-EDF threading-based feature extraction (16kHz) ---
# ✅ XML parser imported successfully
# ✅ Configuration set for 25 patients with 4 threads
# 📁 Data directory: F:/Solo All In One Docs/Evaluating-Noise-Reduction-Techniques/data/sleep_data
# 📊 Output file: ../data/datasets/final_local_dataset.csv
# 🎯 Processing: ALL EDF files per patient (5 EDFs × 6 patients = 30 hours)
# 🧵 Memory-safe: Sequential EDF processing within each patient
# ⚡ Threading: Between patients (4 concurrent patients)
# 🎵 Audio: Downsampling to 16kHz for optimized processing

# %%
# Cell 2: Threading-Compatible Processing Function (All EDFs)
def process_patient_threading(patient_id, data_dir):
    """Process a single patient - ALL EDF files sequentially for memory safety"""
    
    start_time = time.time()
    print(f"🔄 Starting {patient_id} (Thread)...")
    
    # Target sample rate for processing
    TARGET_SAMPLE_RATE = 16000  # 16kHz for optimized processing
    
    def extract_comprehensive_features(audio_frame, sample_rate):
        """Extract comprehensive features from audio frame"""
        try:
            if len(audio_frame) == 0:
                return None
                
            # Basic acoustic features
            rms = float(librosa.feature.rms(y=audio_frame).mean())
            zcr = float(librosa.feature.zero_crossing_rate(y=audio_frame).mean())
            centroid = float(librosa.feature.spectral_centroid(y=audio_frame, sr=sample_rate).mean())
            bandwidth = float(librosa.feature.spectral_bandwidth(y=audio_frame, sr=sample_rate).mean())
            rolloff = float(librosa.feature.spectral_rolloff(y=audio_frame, sr=sample_rate).mean())
            
            # MFCCs (first 8 coefficients)
            mfccs = librosa.feature.mfcc(y=audio_frame, sr=sample_rate, n_mfcc=8)
            mfcc_means = mfccs.mean(axis=1)
            mfcc_stds = mfccs.std(axis=1)
            
            # Temporal features for breathing patterns (5-second windows)
            window_size = int(5 * sample_rate)  # 5 seconds
            num_windows = len(audio_frame) // window_size
            
            if num_windows >= 2:
                rms_windows = []
                zcr_windows = []
                
                for i in range(num_windows):
                    start_idx = i * window_size
                    end_idx = start_idx + window_size
                    window = audio_frame[start_idx:end_idx]
                    
                    rms_windows.append(librosa.feature.rms(y=window).mean())
                    zcr_windows.append(librosa.feature.zero_crossing_rate(y=window).mean())
                
                rms_variability = float(np.std(rms_windows))
                zcr_variability = float(np.std(zcr_windows))
                breathing_regularity = float(1.0 / (1.0 + rms_variability))  # Higher = more regular
            else:
                rms_variability = 0.0
                zcr_variability = 0.0
                breathing_regularity = 0.5
            
            # Silence detection
            silence_threshold = np.percentile(np.abs(audio_frame), 20)  # Bottom 20% as silence
            silence_mask = np.abs(audio_frame) < silence_threshold
            silence_ratio = float(np.mean(silence_mask))
            
            # Breathing pause detection (continuous silence periods)
            silence_changes = np.diff(silence_mask.astype(int))
            pause_starts = np.where(silence_changes == 1)[0]
            pause_ends = np.where(silence_changes == -1)[0]
            
            if len(pause_starts) > 0 and len(pause_ends) > 0:
                if len(pause_ends) < len(pause_starts):
                    pause_ends = np.append(pause_ends, len(audio_frame))
                pause_durations = (pause_ends[:len(pause_starts)] - pause_starts) / sample_rate
                avg_pause_duration = float(np.mean(pause_durations))
                max_pause_duration = float(np.max(pause_durations))
            else:
                avg_pause_duration = 0.0
                max_pause_duration = 0.0
            
            # Combine all features
            features = {
                'clean_rms': rms,
                'clean_zcr': zcr,
                'clean_centroid': centroid,
                'clean_bandwidth': bandwidth,
                'clean_rolloff': rolloff,
                'clean_rms_variability': rms_variability,
                'clean_zcr_variability': zcr_variability,
                'clean_breathing_regularity': breathing_regularity,
                'clean_silence_ratio': silence_ratio,
                'clean_avg_pause_duration': avg_pause_duration,
                'clean_max_pause_duration': max_pause_duration
            }
            
            # Add MFCCs
            for i, (mean_val, std_val) in enumerate(zip(mfcc_means, mfcc_stds), 1):
                features[f'clean_mfcc_{i}_mean'] = float(mean_val)
                features[f'clean_mfcc_{i}_std'] = float(std_val)
            
            return features
            
        except Exception as e:
            print(f"   ⚠️  Feature extraction error in {patient_id}: {e}")
            return None
    
    def get_apnea_label(timestamp, duration, apnea_events, threshold=0.1):
        """Calculate apnea label based on overlap with events"""
        try:
            frame_end = timestamp + duration
            apnea_seconds = 0
            
            for start, end in apnea_events:
                overlap_start = max(timestamp, start)
                overlap_end = min(frame_end, end)
                if overlap_start < overlap_end:
                    apnea_seconds += (overlap_end - overlap_start)
            
            proportion = apnea_seconds / duration
            label = 1 if proportion > threshold else 0
            return label, proportion
        except:
            return 0, 0.0
    
    try:
        # Check if patient directory exists
        patient_dir = os.path.join(data_dir, patient_id)
        if not os.path.exists(patient_dir):
            print(f"❌ {patient_id}: Directory not found: {patient_dir}")
            return []
        
        # Find EDF and RML files
        try:
            edf_files = sorted([f for f in os.listdir(patient_dir) if f.endswith('.edf')])
            rml_files = [f for f in os.listdir(patient_dir) if f.endswith('.rml')]
        except Exception as e:
            print(f"❌ {patient_id}: Cannot list directory files: {e}")
            return []
        
        if not edf_files or not rml_files:
            print(f"❌ {patient_id}: Missing EDF ({len(edf_files)}) or RML ({len(rml_files)}) files")
            return []
        
        print(f"   📁 {patient_id}: Found {len(edf_files)} EDF and {len(rml_files)} RML files")
        
        # Load apnea events (same for all EDF files)
        try:
            rml_path = os.path.join(patient_dir, rml_files[0])
            apnea_data = extract_apnea_events(rml_path, output_csv=None)
            apnea_events = [(float(start), float(end)) for event_type, start, end in apnea_data]
            print(f"   📋 {patient_id}: Found {len(apnea_events)} apnea events")
        except Exception as e:
            print(f"❌ {patient_id}: Cannot load RML file: {e}")
            return []
        
        # Process ALL EDF files sequentially for memory safety
        all_patient_features = []
        total_frames = 0
        
        for edf_idx, edf_file in enumerate(edf_files, 1):
            print(f"   🎵 {patient_id}: Processing EDF {edf_idx}/{len(edf_files)} - {edf_file}")
            
            try:
                edf_path = os.path.join(patient_dir, edf_file)
                raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
                
                if AUDIO_CHANNEL not in raw.ch_names:
                    print(f"   ⚠️  {patient_id}: No {AUDIO_CHANNEL} channel in {edf_file}, skipping")
                    continue
                
                raw.pick_channels([AUDIO_CHANNEL])
                original_sample_rate = int(raw.info['sfreq'])
                duration_minutes = raw.n_times / original_sample_rate / 60
                print(f"      ⏱️  Duration: {duration_minutes:.1f} min, Original SR: {original_sample_rate} Hz → Target: {TARGET_SAMPLE_RATE} Hz")
                
                # Frame parameters using TARGET_SAMPLE_RATE
                frame_samples = int(FRAME_DURATION * TARGET_SAMPLE_RATE)
                step_samples = int(frame_samples * (1 - OVERLAP_RATIO))
                
                # Calculate original frame size for loading
                original_frame_samples = int(FRAME_DURATION * original_sample_rate)
                original_step_samples = int(original_frame_samples * (1 - OVERLAP_RATIO))
                
                # Calculate time offset for this EDF (assuming sequential recordings)
                time_offset = (edf_idx - 1) * 60 * 60  # Each EDF = 1 hour, offset in seconds
                
                # Extract features from frames in this EDF
                edf_frame_count = 0
                
                for frame_start in range(0, raw.n_times - original_frame_samples + 1, original_step_samples):
                    frame_end = frame_start + original_frame_samples
                    timestamp = (frame_start / original_sample_rate) + time_offset  # Add offset for multi-EDF
                    
                    # Load audio frame at original sample rate
                    try:
                        audio_frame, _ = raw[:, frame_start:frame_end]
                        audio_frame = audio_frame.flatten()
                        
                        # Downsample to target sample rate
                        if original_sample_rate != TARGET_SAMPLE_RATE:
                            audio_frame = librosa.resample(audio_frame, 
                                                         orig_sr=original_sample_rate, 
                                                         target_sr=TARGET_SAMPLE_RATE)
                        
                    except Exception as e:
                        print(f"      ⚠️  Frame {edf_frame_count} load/downsample failed: {e}")
                        continue
                    
                    # Extract features using TARGET_SAMPLE_RATE
                    features = extract_comprehensive_features(audio_frame, TARGET_SAMPLE_RATE)
                    if features is None:
                        continue
                    
                    # Get apnea label
                    apnea_label, apnea_proportion = get_apnea_label(timestamp, FRAME_DURATION, apnea_events, APNEA_THRESHOLD)
                    
                    # Create record
                    record = {
                        'patient_id': patient_id,
                        'edf_file': edf_file,  # Track which EDF file
                        'timestamp': float(timestamp),
                        'frame_duration': FRAME_DURATION,
                        'sample_rate': TARGET_SAMPLE_RATE,  # Track downsampled rate
                        'apnea_label': int(apnea_label),
                        'apnea_proportion': float(apnea_proportion),
                        **features
                    }
                    
                    all_patient_features.append(record)
                    edf_frame_count += 1
                    total_frames += 1
                    
                    # Progress every 100 frames per EDF
                    if edf_frame_count % 100 == 0:
                        print(f"      🔄 {edf_file}: {edf_frame_count} frames processed...")
                
                print(f"      ✅ {edf_file}: {edf_frame_count} frames extracted (downsampled to {TARGET_SAMPLE_RATE} Hz)")
                
                # Clear memory after each EDF
                del raw
                
            except Exception as e:
                print(f"   ❌ {patient_id}: Failed processing {edf_file}: {e}")
                continue
        
        elapsed = time.time() - start_time
        apnea_count = sum(1 for f in all_patient_features if f['apnea_label'] == 1)
        print(f"✅ {patient_id}: {total_frames} total frames, {apnea_count} apnea ({elapsed:.1f}s)")
        
        return all_patient_features
        
    except Exception as e:
        print(f"❌ {patient_id}: Critical failure: {e}")
        import traceback
        traceback.print_exc()
        return []

print("✅ Multi-EDF threading-compatible processing function defined (with 16kHz downsampling)")
# Out:
# ✅ Multi-EDF threading-compatible processing function defined (with 16kHz downsampling)

# %%
# Cell 3: Run Threading-Based Processing
def run_threading_processing():
    """Execute threading-based processing of all patients"""
    
    print(f"🧵 STARTING THREADING-BASED PROCESSING")
    print(f"👥 Patients: {PATIENTS_TO_PROCESS}")
    print(f"🔧 Threads: {MAX_WORKERS}")
    print(f"{'='*60}")
    
    start_time = time.time()
    all_features = []
    completed = 0
    failed = 0
    
    # Use ThreadPoolExecutor for parallel processing
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        # Submit all jobs
        future_to_patient = {
            executor.submit(process_patient_threading, patient, PATIENT_DATA_DIR): patient 
            for patient in PATIENTS_TO_PROCESS
        }
        
        print(f"📤 Submitted {len(future_to_patient)} patient processing jobs")
        
        # Collect results as they complete
        for future in as_completed(future_to_patient):
            patient = future_to_patient[future]
            try:
                # Get result with timeout
                result = future.result(timeout=600)  # 10 minute timeout per patient
                
                if result:
                    all_features.extend(result)
                    completed += 1
                    print(f"🎯 Progress: {completed}/{len(PATIENTS_TO_PROCESS)} completed ({patient}) - {len(result)} frames")
                else:
                    failed += 1
                    print(f"⚠️  {patient}: No features extracted")
                    
            except Exception as e:
                failed += 1
                print(f"❌ {patient}: Exception occurred: {e}")
                import traceback
                traceback.print_exc()
    
    total_time = time.time() - start_time
    
    # Results summary
    print(f"\n{'='*60}")
    print(f"🏁 THREADING PROCESSING COMPLETE!")
    print(f"⏱️  Total time: {total_time:.1f} seconds ({total_time/60:.1f} minutes)")
    print(f"✅ Completed: {completed}")
    print(f"❌ Failed: {failed}")
    print(f"📊 Total features: {len(all_features):,}")
    
    if all_features:
        # Convert to DataFrame
        df = pd.DataFrame(all_features)
        
        # Save to CSV
        df.to_csv(OUTPUT_FILE, index=False)
        
        # Dataset statistics
        apnea_count = df['apnea_label'].sum()
        apnea_rate = df['apnea_label'].mean() * 100
        
        print(f"\n📋 DATASET STATISTICS:")
        print(f"📄 File saved: {OUTPUT_FILE}")
        print(f"📊 Shape: {df.shape}")
        print(f"👥 Unique patients: {df['patient_id'].nunique()}")
        print(f"🚨 Apnea frames: {apnea_count:,} ({apnea_rate:.1f}%)")
        print(f"😴 Normal frames: {len(df) - apnea_count:,} ({100-apnea_rate:.1f}%)")
        
        # Feature columns
        feature_cols = [col for col in df.columns if col.startswith('clean_')]
        print(f"🎯 Feature count: {len(feature_cols)}")
        
        # Per-patient breakdown
        print(f"\n👤 PER-PATIENT BREAKDOWN:")
        patient_stats = df.groupby('patient_id').agg({
            'apnea_label': ['count', 'sum', 'mean']
        }).round(3)
        
        for patient in df['patient_id'].unique():
            count = patient_stats.loc[patient, ('apnea_label', 'count')]
            apnea = patient_stats.loc[patient, ('apnea_label', 'sum')]
            rate = patient_stats.loc[patient, ('apnea_label', 'mean')] * 100
            print(f"   {patient}: {count} frames, {apnea} apnea ({rate:.1f}%)")
        
        # Display sample
        print(f"\n📋 SAMPLE DATA:")
        print(df.head())
        
        # Feature correlation analysis
        if len(feature_cols) > 0:
            correlations = df[feature_cols].corrwith(df['apnea_label']).abs().sort_values(ascending=False)
            print(f"\n🔗 TOP 5 FEATURE CORRELATIONS WITH APNEA:")
            for feature, corr in correlations.head().items():
                print(f"   {feature}: {corr:.3f}")
        
        return df
    else:
        print(f"❌ No features extracted from any patient")
        return None

print("✅ Threading processing function ready")
# Out:
# ✅ Threading processing function ready

# %%
# Cell 4: Execute Threading Processing
import time
print("🧵 EXECUTING THREADING-BASED FEATURE EXTRACTION")
print(f"Time started: {time.strftime('%Y-%m-%d %H:%M:%S')}")

# Run the threading processing
dataset = run_threading_processing()

if dataset is not None:
    print(f"\n🎉 SUCCESS! Dataset ready for model training.")
    print(f"📁 Saved as: {OUTPUT_FILE}")
    print(f"🚀 Threading approach avoided Windows multiprocessing issues!")
else:
    print(f"\n❌ Processing failed. Check error messages above.")

print(f"\nTime finished: {time.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# 🧵 EXECUTING THREADING-BASED FEATURE EXTRACTION
# Time started: 2025-07-28 14:51:31
# 🧵 STARTING THREADING-BASED PROCESSING
# 👥 Patients: ['patient_01', 'patient_02', 'patient_03', 'patient_04', 'patient_05', 'patient_06', 'patient_07', 'patient_07', 'patient_08', 'patient_09', 'patient_10', 'patient_11', 'patient_12', 'patient_13', 'patient_14', 'patient_15', 'patient_16', 'patient_17', 'patient_18', 'patient_19', 'patient_20', 'patient_21', 'patient_22', 'patient_23', 'patient_24']
# 🔧 Threads: 4
# ============================================================
# 🔄 Starting patient_01 (Thread)...
# 🔄 Starting patient_02 (Thread)...
# 🔄 Starting patient_03 (Thread)...
#    📁 patient_01: Found 5 EDF and 1 RML files
# 🔄 Starting patient_04 (Thread)...
#    📁 patient_02: Found 5 EDF and 1 RML files
# 📤 Submitted 25 patient processing jobs
#    📁 patient_03: Found 4 EDF and 1 RML files
#    📁 patient_04: Found 5 EDF and 1 RML files
# ObstructiveApnea: 41.0s to 54.5s (duration: 13.5s)
# ObstructiveApnea: 91.5s to 110.5s (duration: 19.0s)
# ObstructiveApnea: 436.0s to 448.0s (duration: 12.0s)
# ObstructiveApnea: 472.0s to 482.5s (duration: 10.5s)
# ObstructiveApnea: 494.0s to 505.0s (duration: 11.0s)
# ObstructiveApnea: 638.0s to 653.5s (duration: 15.5s)
# ObstructiveApnea: 668.0s to 680.5s (duration: 12.5s)
# ObstructiveApnea: 744.0s to 754.5s (duration: 10.5s)
# ObstructiveApnea: 769.0s to 781.5s (duration: 12.5s)
# ObstructiveApnea: 798.0s to 809.5s (duration: 11.5s)
# ObstructiveApnea: 840.5s to 851.0s (duration: 10.5s)
# Hypopnea: 864.0s to 877.5s (duration: 13.5s)
# ObstructiveApnea: 950.5s to 965.0s (duration: 14.5s)
# ObstructiveApnea: 1002.0s to 1013.0s (duration: 11.0s)
# ObstructiveApnea: 1042.5s to 1056.0s (duration: 13.5s)
# Hypopnea: 1083.0s to 1102.5s (duration: 19.5s)
# Hypopnea: 1160.0s to 1185.0s (duration: 25.0s)
# ObstructiveApnea: 1203.0s to 1215.5s (duration: 12.5s)
# ObstructiveApnea: 1323.5s to 1335.0s (duration: 11.5s)
# ObstructiveApnea: 1348.5s to 1360.5s (duration: 12.0s)
# ObstructiveApnea: 1395.0s to 1406.5s (duration: 11.5s)
# ObstructiveApnea: 1451.0s to 1462.0s (duration: 11.0s)
# ObstructiveApnea: 1482.5s to 1494.0s (duration: 11.5s)
# ObstructiveApnea: 1519.0s to 1533.5s (duration: 14.5s)
# MixedApnea: 1552.5s to 1568.0s (duration: 15.5s)
# ObstructiveApnea: 1593.0s to 1608.0s (duration: 15.0s)
# ObstructiveApnea: 3613.5s to 3626.0s (duration: 12.5s)
# Hypopnea: 3675.5s to 3692.5s (duration: 17.0s)
# Hypopnea: 3786.5s to 3797.5s (duration: 11.0s)
# Hypopnea: 3868.0s to 3883.5s (duration: 15.5s)
# Hypopnea: 3912.5s to 3927.5s (duration: 15.0s)
# Hypopnea: 3959.5s to 3976.5s (duration: 17.0s)
# Hypopnea: 4048.0s to 4063.0s (duration: 15.0s)
# Hypopnea: 4189.0s to 4205.0s (duration: 16.0s)
# ObstructiveApnea: 4228.5s to 4241.5s (duration: 13.0s)
# ObstructiveApnea: 4267.5s to 4282.0s (duration: 14.5s)
# Hypopnea: 4304.5s to 4321.5s (duration: 17.0s)
# Hypopnea: 4356.5s to 4370.5s (duration: 14.0s)
# ObstructiveApnea: 4401.5s to 4412.5s (duration: 11.0s)
# ObstructiveApnea: 4436.0s to 4447.0s (duration: 11.0s)
# ObstructiveApnea: 4468.0s to 4482.5s (duration: 14.5s)
# ObstructiveApnea: 4531.0s to 4545.0s (duration: 14.0s)
# ObstructiveApnea: 10727.0s to 10741.0s (duration: 14.0s)
# Hypopnea: 10774.0s to 10801.5s (duration: 27.5s)
# ObstructiveApnea: 10831.5s to 10846.5s (duration: 15.0s)
# Hypopnea: 10867.0s to 10887.0s (duration: 20.0s)
# Hypopnea: 10916.0s to 10928.5s (duration: 12.5s)
# Hypopnea: 11420.0s to 11440.0s (duration: 20.0s)
# Hypopnea: 11472.5s to 11505.5s (duration: 33.0s)
# Hypopnea: 11528.0s to 11548.5s (duration: 20.5s)
# MixedApnea: 11987.5s to 12002.5s (duration: 15.0s)
# Hypopnea: 12032.5s to 12048.5s (duration: 16.0s)
# Hypopnea: 12825.5s to 12838.5s (duration: 13.0s)
# ObstructiveApnea: 13018.5s to 13032.0s (duration: 13.5s)
# ObstructiveApnea: 13099.0s to 13120.0s (duration: 21.0s)
# ObstructiveApnea: 13155.0s to 13167.5s (duration: 12.5s)
# ObstructiveApnea: 13199.0s to 13218.0s (duration: 19.0s)
# ObstructiveApnea: 13260.5s to 13274.5s (duration: 14.0s)
# ObstructiveApnea: 13297.5s to 13317.0s (duration: 19.5s)
# ObstructiveApnea: 13374.0s to 13388.0s (duration: 14.0s)
# ObstructiveApnea: 13410.5s to 13426.0s (duration: 15.5s)
# ObstructiveApnea: 13482.0s to 13500.5s (duration: 18.5s)
# ObstructiveApnea: 13552.5s to 13567.5s (duration: 15.0s)
# ObstructiveApnea: 13594.0s to 13606.5s (duration: 12.5s)
# ObstructiveApnea: 13625.0s to 13640.5s (duration: 15.5s)
# Hypopnea: 13682.0s to 13700.5s (duration: 18.5s)
# Hypopnea: 13735.5s to 13751.0s (duration: 15.5s)
# Hypopnea: 13772.0s to 13790.5s (duration: 18.5s)
# Hypopnea: 13816.5s to 13830.0s (duration: 13.5s)
# Hypopnea: 13864.5s to 13880.5s (duration: 16.0s)
# ObstructiveApnea: 14077.5s to 14090.0s (duration: 12.5s)
# ObstructiveApnea: 14123.5s to 14136.5s (duration: 13.0s)
# Hypopnea: 14165.0s to 14179.0s (duration: 14.0s)
# Hypopnea: 14209.0s to 14228.5s (duration: 19.5s)
# Hypopnea: 14288.0s to 14302.5s (duration: 14.5s)
# ObstructiveApnea: 14442.0s to 14455.5s (duration: 13.5s)
#    📋 patient_01: Found 165 apnea events
#    🎵 patient_01: Processing EDF 1/5 - 00001000-100507[001].edf
# Hypopnea: 483.5s to 496.5s (duration: 13.0s)
# Hypopnea: 525.0s to 542.0s (duration: 17.0s)
# ObstructiveApnea: 692.5s to 704.5s (duration: 12.0s)
# Hypopnea: 725.5s to 737.0s (duration: 11.5s)
# Hypopnea: 794.5s to 811.5s (duration: 17.0s)
# Hypopnea: 828.5s to 840.5s (duration: 12.0s)
# ObstructiveApnea: 858.0s to 871.5s (duration: 13.5s)
# ObstructiveApnea: 972.0s to 984.5s (duration: 12.5s)
# ObstructiveApnea: 1034.0s to 1050.0s (duration: 16.0s)
# ObstructiveApnea: 1070.5s to 1087.5s (duration: 17.0s)
# ObstructiveApnea: 1127.5s to 1151.0s (duration: 23.5s)
# Hypopnea: 3751.5s to 3765.0s (duration: 13.5s)
# MixedApnea: 3779.0s to 3793.0s (duration: 14.0s)
# Hypopnea: 3815.0s to 3829.0s (duration: 14.0s)
# Hypopnea: 3840.0s to 3854.0s (duration: 14.0s)
# Hypopnea: 3871.0s to 3883.5s (duration: 12.5s)
# MixedApnea: 3896.5s to 3909.0s (duration: 12.5s)
# MixedApnea: 3947.0s to 3963.0s (duration: 16.0s)
# Hypopnea: 3983.5s to 3995.0s (duration: 11.5s)
# ObstructiveApnea: 4025.0s to 4036.0s (duration: 11.0s)
# Hypopnea: 4047.0s to 4058.5s (duration: 11.5s)
# Hypopnea: 4072.0s to 4082.5s (duration: 10.5s)
# Hypopnea: 4092.0s to 4102.5s (duration: 10.5s)
# Hypopnea: 4118.0s to 4129.0s (duration: 11.0s)
# Hypopnea: 4161.0s to 4173.5s (duration: 12.5s)
# Hypopnea: 4192.5s to 4204.5s (duration: 12.0s)
# MixedApnea: 4248.0s to 4260.0s (duration: 12.0s)
# Hypopnea: 4275.0s to 4285.5s (duration: 10.5s)
# Hypopnea: 4295.0s to 4305.0s (duration: 10.0s)
# MixedApnea: 4322.0s to 4332.5s (duration: 10.5s)
# Hypopnea: 4433.0s to 4443.0s (duration: 10.0s)
# Hypopnea: 4902.0s to 4913.0s (duration: 11.0s)
# Hypopnea: 5008.5s to 5019.5s (duration: 11.0s)
# Hypopnea: 5036.5s to 5047.5s (duration: 11.0s)
# Hypopnea: 5058.5s to 5068.5s (duration: 10.0s)
# MixedApnea: 5168.0s to 5178.0s (duration: 10.0s)
# MixedApnea: 5188.5s to 5200.5s (duration: 12.0s)
# ObstructiveApnea: 5265.0s to 5275.5s (duration: 10.5s)
# Hypopnea: 5288.0s to 5298.0s (duration: 10.0s)
# Hypopnea: 5326.5s to 5337.5s (duration: 11.0s)
# MixedApnea: 5426.5s to 5436.5s (duration: 10.0s)
# CentralApnea: 5475.5s to 5485.5s (duration: 10.0s)
# Hypopnea: 5501.0s to 5511.5s (duration: 10.5s)
# Hypopnea: 5522.0s to 5532.0s (duration: 10.0s)
# ObstructiveApnea: 5542.0s to 5553.0s (duration: 11.0s)
# Hypopnea: 5565.0s to 5577.5s (duration: 12.5s)
# Hypopnea: 5620.0s to 5631.0s (duration: 11.0s)
# Hypopnea: 5657.5s to 5668.5s (duration: 11.0s)
# Hypopnea: 5683.5s to 5696.5s (duration: 13.0s)
# Hypopnea: 5826.5s to 5837.5s (duration: 11.0s)
# CentralApnea: 5845.0s to 5855.0s (duration: 10.0s)
# Hypopnea: 5899.0s to 5909.0s (duration: 10.0s)
# MixedApnea: 5978.5s to 5988.5s (duration: 10.0s)
# MixedApnea: 6331.0s to 6342.0s (duration: 11.0s)
# ObstructiveApnea: 6401.5s to 6414.0s (duration: 12.5s)
# Hypopnea: 7007.0s to 7018.0s (duration: 11.0s)
# Hypopnea: 7029.0s to 7040.5s (duration: 11.5s)
# Hypopnea: 7195.5s to 7210.0s (duration: 14.5s)
# Hypopnea: 7258.0s to 7270.5s (duration: 12.5s)
# ObstructiveApnea: 7285.0s to 7295.0s (duration: 10.0s)
# Hypopnea: 7306.0s to 7317.0s (duration: 11.0s)
# MixedApnea: 7336.5s to 7347.5s (duration: 11.0s)
# Hypopnea: 7377.0s to 7388.5s (duration: 11.5s)
# Hypopnea: 7397.5s to 7408.5s (duration: 11.0s)
# Hypopnea: 7424.0s to 7434.5s (duration: 10.5s)
# ObstructiveApnea: 7448.5s to 7461.0s (duration: 12.5s)
# ObstructiveApnea: 7470.5s to 7485.0s (duration: 14.5s)
# MixedApnea: 7559.5s to 7570.5s (duration: 11.0s)
# ObstructiveApnea: 7584.5s to 7597.0s (duration: 12.5s)
# Hypopnea: 7614.5s to 7626.0s (duration: 11.5s)
# Hypopnea: 7642.0s to 7652.5s (duration: 10.5s)
# ObstructiveApnea: 7664.0s to 7676.5s (duration: 12.5s)
# ObstructiveApnea: 7695.0s to 7709.5s (duration: 14.5s)
# MixedApnea: 7726.0s to 7741.0s (duration: 15.0s)
# Hypopnea: 7759.5s to 7777.5s (duration: 18.0s)
# Hypopnea: 7792.0s to 7803.0s (duration: 11.0s)
# ObstructiveApnea: 7816.0s to 7831.0s (duration: 15.0s)
# Hypopnea: 7886.5s to 7897.0s (duration: 10.5s)
# Hypopnea: 7929.5s to 7940.5s (duration: 11.0s)
# MixedApnea: 7959.0s to 7969.5s (duration: 10.5s)
# Hypopnea: 7987.0s to 8000.0s (duration: 13.0s)
# Hypopnea: 8022.5s to 8033.5s (duration: 11.0s)
# Hypopnea: 8050.0s to 8063.5s (duration: 13.5s)
# Hypopnea: 8084.5s to 8095.5s (duration: 11.0s)
# Hypopnea: 8110.0s to 8122.0s (duration: 12.0s)
# Hypopnea: 8140.0s to 8150.0s (duration: 10.0s)
# MixedApnea: 8243.5s to 8253.5s (duration: 10.0s)
# Hypopnea: 10497.5s to 10509.5s (duration: 12.0s)
# Hypopnea: 10526.5s to 10539.0s (duration: 12.5s)
# Hypopnea: 10551.5s to 10562.5s (duration: 11.0s)
# Hypopnea: 10609.0s to 10621.5s (duration: 12.5s)
# Hypopnea: 10700.5s to 10711.5s (duration: 11.0s)
# Hypopnea: 11053.5s to 11066.0s (duration: 12.5s)
# ObstructiveApnea: 11106.0s to 11117.5s (duration: 11.5s)
# MixedApnea: 11148.5s to 11159.0s (duration: 10.5s)
# Hypopnea: 11210.0s to 11223.0s (duration: 13.0s)
# Hypopnea: 11242.0s to 11253.0s (duration: 11.0s)
# Hypopnea: 11273.0s to 11283.5s (duration: 10.5s)
# Hypopnea: 11312.5s to 11323.5s (duration: 11.0s)
# Hypopnea: 11346.0s to 11357.0s (duration: 11.0s)
# Hypopnea: 11376.0s to 11389.0s (duration: 13.0s)
# Hypopnea: 11414.5s to 11427.5s (duration: 13.0s)
# Hypopnea: 11446.0s to 11464.0s (duration: 18.0s)
# Hypopnea: 11613.5s to 11627.5s (duration: 14.0s)
# Hypopnea: 11642.0s to 11652.0s (duration: 10.0s)
# Hypopnea: 11724.0s to 11735.5s (duration: 11.5s)
# Hypopnea: 11792.5s to 11803.0s (duration: 10.5s)
# Hypopnea: 11838.5s to 11849.0s (duration: 10.5s)
# Hypopnea: 11871.0s to 11882.5s (duration: 11.5s)
# Hypopnea: 11921.5s to 11933.0s (duration: 11.5s)
# Hypopnea: 11998.5s to 12010.5s (duration: 12.0s)
# Hypopnea: 12049.0s to 12064.5s (duration: 15.5s)
# Hypopnea: 12090.5s to 12102.0s (duration: 11.5s)
# Hypopnea: 12147.0s to 12158.5s (duration: 11.5s)
# MixedApnea: 12401.5s to 12418.0s (duration: 16.5s)
# ObstructiveApnea: 12438.5s to 12448.5s (duration: 10.0s)
# ObstructiveApnea: 12470.5s to 12484.0s (duration: 13.5s)
# ObstructiveApnea: 12500.5s to 12512.5s (duration: 12.0s)
# MixedApnea: 12530.5s to 12544.0s (duration: 13.5s)
# ObstructiveApnea: 12563.5s to 12575.0s (duration: 11.5s)
# ObstructiveApnea: 12594.0s to 12605.0s (duration: 11.0s)
# ObstructiveApnea: 12621.5s to 12635.5s (duration: 14.0s)
# ObstructiveApnea: 12652.0s to 12670.5s (duration: 18.5s)
# ObstructiveApnea: 12689.0s to 12701.5s (duration: 12.5s)
# ObstructiveApnea: 12722.5s to 12737.0s (duration: 14.5s)
# ObstructiveApnea: 12756.0s to 12769.5s (duration: 13.5s)
# ObstructiveApnea: 12791.0s to 12803.5s (duration: 12.5s)
# ObstructiveApnea: 12820.5s to 12839.5s (duration: 19.0s)
# Hypopnea: 12858.0s to 12873.0s (duration: 15.0s)
# Hypopnea: 13482.5s to 13493.0s (duration: 10.5s)
# ObstructiveApnea: 13513.0s to 13525.5s (duration: 12.5s)
# Hypopnea: 13575.0s to 13589.5s (duration: 14.5s)
# Hypopnea: 13603.5s to 13623.0s (duration: 19.5s)
# Hypopnea: 13645.5s to 13663.5s (duration: 18.0s)
# Hypopnea: 13686.0s to 13701.5s (duration: 15.5s)
# Hypopnea: 13720.0s to 13730.5s (duration: 10.5s)
# Hypopnea: 773.0s to 784.0s (duration: 11.0s)
# Hypopnea: 820.0s to 830.0s (duration: 10.0s)
# ObstructiveApnea: 978.5s to 989.0s (duration: 10.5s)
# ObstructiveApnea: 1008.0s to 1018.0s (duration: 10.0s)
# ObstructiveApnea: 1038.5s to 1049.0s (duration: 10.5s)
# ObstructiveApnea: 1067.0s to 1077.5s (duration: 10.5s)
# Hypopnea: 1101.0s to 1111.0s (duration: 10.0s)
# Hypopnea: 1128.0s to 1138.0s (duration: 10.0s)
# ObstructiveApnea: 1157.0s to 1167.0s (duration: 10.0s)
# Hypopnea: 1184.0s to 1194.5s (duration: 10.5s)
# ObstructiveApnea: 1213.5s to 1224.5s (duration: 11.0s)
# ObstructiveApnea: 1241.0s to 1252.5s (duration: 11.5s)
# ObstructiveApnea: 1280.0s to 1290.5s (duration: 10.5s)
# Hypopnea: 1317.0s to 1327.0s (duration: 10.0s)
# Hypopnea: 1354.5s to 1365.0s (duration: 10.5s)
# Hypopnea: 1427.5s to 1439.0s (duration: 11.5s)
# Hypopnea: 1586.5s to 1597.5s (duration: 11.0s)
# ObstructiveApnea: 12590.0s to 12608.5s (duration: 18.5s)
# MixedApnea: 12624.5s to 12640.0s (duration: 15.5s)
# ObstructiveApnea: 12652.5s to 12671.0s (duration: 18.5s)
# ObstructiveApnea: 12689.5s to 12708.0s (duration: 18.5s)
# ObstructiveApnea: 12721.5s to 12742.5s (duration: 21.0s)
# ObstructiveApnea: 12756.5s to 12780.0s (duration: 23.5s)
# ObstructiveApnea: 12800.5s to 12818.5s (duration: 18.0s)
# MixedApnea: 12835.5s to 12856.5s (duration: 21.0s)
# ObstructiveApnea: 12873.0s to 12889.0s (duration: 16.0s)
# ObstructiveApnea: 12906.0s to 12927.0s (duration: 21.0s)
# ObstructiveApnea: 12938.0s to 12956.5s (duration: 18.5s)
# ObstructiveApnea: 12973.5s to 12993.0s (duration: 19.5s)
# ObstructiveApnea: 13028.0s to 13038.0s (duration: 10.0s)
# Hypopnea: 13216.5s to 13227.0s (duration: 10.5s)
# Hypopnea: 13245.5s to 13257.0s (duration: 11.5s)
# MixedApnea: 13273.0s to 13285.0s (duration: 12.0s)
# Hypopnea: 13310.5s to 13321.0s (duration: 10.5s)
# Hypopnea: 13339.5s to 13357.0s (duration: 17.5s)
# ObstructiveApnea: 13553.5s to 13564.5s (duration: 11.0s)
#    📋 patient_03: Found 307 apnea events
#    🎵 patient_03: Processing EDF 1/4 - 00001059-100507[001].edf
# ObstructiveApnea: 13774.0s to 13787.0s (duration: 13.0s)
# MixedApnea: 13804.5s to 13821.0s (duration: 16.5s)
# ObstructiveApnea: 13836.5s to 13852.0s (duration: 15.5s)
# ObstructiveApnea: 13871.0s to 13884.5s (duration: 13.5s)
# Hypopnea: 13915.0s to 13925.5s (duration: 10.5s)
# ObstructiveApnea: 13950.5s to 13967.5s (duration: 17.0s)
# MixedApnea: 14008.5s to 14019.5s (duration: 11.0s)
# Hypopnea: 14042.0s to 14054.5s (duration: 12.5s)
# Hypopnea: 14069.5s to 14086.5s (duration: 17.0s)
# Hypopnea: 14108.0s to 14125.5s (duration: 17.5s)
# Hypopnea: 14144.5s to 14156.5s (duration: 12.0s)
#    📋 patient_02: Found 156 apnea events
#    🎵 patient_02: Processing EDF 1/5 - 00001045-100507[001].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
# Setting channel info structure...
# Creating raw.info structure...
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001120-100507[001].edf: 100 frames processed...
#       🔄 00001000-100507[001].edf: 100 frames processed...
#       🔄 00001045-100507[001].edf: 100 frames processed...      🔄 00001059-100507[001].edf: 100 frames processed...
#
#       🔄 00001120-100507[001].edf: 200 frames processed...
#       🔄 00001000-100507[001].edf: 200 frames processed...
#       🔄 00001059-100507[001].edf: 200 frames processed...
#       🔄 00001045-100507[001].edf: 200 frames processed...
#       ✅ 00001000-100507[001].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_01: Processing EDF 2/5 - 00001000-100507[002].edf
#       ✅ 00001120-100507[001].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_04: Processing EDF 2/5 - 00001120-100507[002].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       ✅ 00001045-100507[001].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_02: Processing EDF 2/5 - 00001045-100507[002].edf
#       ✅ 00001059-100507[001].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_03: Processing EDF 2/4 - 00001059-100507[002].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001000-100507[002].edf: 100 frames processed...
#       🔄 00001120-100507[002].edf: 100 frames processed...
# ...
# ObstructiveApnea: 21479.5s to 21502.5s (duration: 23.0s)
# CentralApnea: 21526.5s to 21536.5s (duration: 10.0s)
# MixedApnea: 21564.5s to 21587.0s (duration: 22.5s)
# MixedApnea: 21603.5s to 21620.0s (duration: 16.5s)
# ObstructiveApnea: 21635.0s to 21649.5s (duration: 14.5s)
# MixedApnea: 21664.0s to 21679.5s (duration: 15.5s)
# ObstructiveApnea: 21735.5s to 21746.0s (duration: 10.5s)
# CentralApnea: 21767.0s to 21781.0s (duration: 14.0s)
# CentralApnea: 21800.5s to 21810.5s (duration: 10.0s)
# CentralApnea: 21824.0s to 21834.0s (duration: 10.0s)
# CentralApnea: 21844.5s to 21854.5s (duration: 10.0s)
# MixedApnea: 21867.5s to 21888.5s (duration: 21.0s)
# CentralApnea: 21912.5s to 21928.0s (duration: 15.5s)
# CentralApnea: 21944.5s to 21959.0s (duration: 14.5s)
# CentralApnea: 21973.0s to 21991.5s (duration: 18.5s)
# CentralApnea: 22012.5s to 22025.0s (duration: 12.5s)
# MixedApnea: 22035.0s to 22059.5s (duration: 24.5s)
# Hypopnea: 22130.0s to 22145.0s (duration: 15.0s)
# ObstructiveApnea: 22202.5s to 22218.0s (duration: 15.5s)
# ObstructiveApnea: 22240.5s to 22251.5s (duration: 11.0s)
# Hypopnea: 22378.0s to 22391.0s (duration: 13.0s)
# ObstructiveApnea: 22407.0s to 22418.0s (duration: 11.0s)
# ObstructiveApnea: 22448.5s to 22465.5s (duration: 17.0s)
# ObstructiveApnea: 22482.0s to 22501.5s (duration: 19.5s)
# Hypopnea: 22516.0s to 22537.5s (duration: 21.5s)
# ObstructiveApnea: 22565.0s to 22582.5s (duration: 17.5s)
# ObstructiveApnea: 22612.5s to 22640.0s (duration: 27.5s)
# ObstructiveApnea: 23559.0s to 23576.5s (duration: 17.5s)
# Hypopnea: 23602.0s to 23640.5s (duration: 38.5s)
# Hypopnea: 23677.5s to 23696.0s (duration: 18.5s)
# Hypopnea: 23797.5s to 23818.5s (duration: 21.0s)
# Hypopnea: 23990.5s to 24040.0s (duration: 49.5s)
# ObstructiveApnea: 24081.5s to 24104.0s (duration: 22.5s)
# ObstructiveApnea: 24120.0s to 24145.5s (duration: 25.5s)
# ObstructiveApnea: 24155.5s to 24165.5s (duration: 10.0s)
# ObstructiveApnea: 24180.0s to 24190.0s (duration: 10.0s)
# ObstructiveApnea: 24204.0s to 24218.5s (duration: 14.5s)
#    📋 patient_23: Found 344 apnea events
#    🎵 patient_23: Processing EDF 1/7 - 00001631-100507[001].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001597-100507[007].edf: 100 frames processed...
#       ✅ 00001597-100507[007].edf: 139 frames extracted (downsampled to 16000 Hz)
# ✅ patient_20: 1573 total frames, 1077 apnea (1889.7s)
# 🔄 Starting patient_24 (Thread)...
# 🎯 Progress: 21/25 completed (patient_20) - 1573 frames
#    📁 patient_24: Found 4 EDF and 1 RML files
# Hypopnea: 503.5s to 520.5s (duration: 17.0s)
# Hypopnea: 787.5s to 802.5s (duration: 15.0s)
# Hypopnea: 1443.0s to 1454.0s (duration: 11.0s)
# CentralApnea: 2450.5s to 2469.0s (duration: 18.5s)
# Hypopnea: 2818.0s to 2828.5s (duration: 10.5s)
# Hypopnea: 3315.0s to 3328.5s (duration: 13.5s)
# Hypopnea: 3361.5s to 3380.0s (duration: 18.5s)
# Hypopnea: 3432.5s to 3446.0s (duration: 13.5s)
# Hypopnea: 3467.5s to 3478.5s (duration: 11.0s)
# Hypopnea: 3493.0s to 3506.5s (duration: 13.5s)
# Hypopnea: 3540.5s to 3551.5s (duration: 11.0s)
# Hypopnea: 3566.0s to 3577.0s (duration: 11.0s)
# ObstructiveApnea: 3600.5s to 3615.0s (duration: 14.5s)
# Hypopnea: 3650.5s to 3674.0s (duration: 23.5s)
# Hypopnea: 3763.5s to 3774.5s (duration: 11.0s)
# ObstructiveApnea: 3836.5s to 3854.5s (duration: 18.0s)
# ObstructiveApnea: 3884.0s to 3901.0s (duration: 17.0s)
# Hypopnea: 3934.5s to 3951.5s (duration: 17.0s)
# Hypopnea: 3981.5s to 3994.5s (duration: 13.0s)
# ObstructiveApnea: 4019.5s to 4032.0s (duration: 12.5s)
# Hypopnea: 4093.5s to 4106.0s (duration: 12.5s)
# ObstructiveApnea: 4156.0s to 4172.5s (duration: 16.5s)
# Hypopnea: 4200.5s to 4217.5s (duration: 17.0s)
# MixedApnea: 4233.0s to 4248.0s (duration: 15.0s)
# Hypopnea: 4261.0s to 4274.0s (duration: 13.0s)
# Hypopnea: 4315.5s to 4335.0s (duration: 19.5s)
# ObstructiveApnea: 4418.0s to 4429.5s (duration: 11.5s)
# ObstructiveApnea: 4459.5s to 4474.0s (duration: 14.5s)
# ObstructiveApnea: 4488.0s to 4498.0s (duration: 10.0s)
# ObstructiveApnea: 4513.5s to 4532.5s (duration: 19.0s)
# Hypopnea: 4580.0s to 4591.0s (duration: 11.0s)
# ObstructiveApnea: 4615.5s to 4628.5s (duration: 13.0s)
# ObstructiveApnea: 4655.0s to 4669.0s (duration: 14.0s)
# Hypopnea: 4761.0s to 4774.5s (duration: 13.5s)
# ObstructiveApnea: 4861.0s to 4886.0s (duration: 25.0s)
# ObstructiveApnea: 5488.5s to 5512.5s (duration: 24.0s)
# ObstructiveApnea: 5602.0s to 5620.5s (duration: 18.5s)
# ObstructiveApnea: 5655.0s to 5671.5s (duration: 16.5s)
# Hypopnea: 5697.5s to 5714.0s (duration: 16.5s)
# CentralApnea: 5787.5s to 5805.5s (duration: 18.0s)
# CentralApnea: 5849.5s to 5864.0s (duration: 14.5s)
# Hypopnea: 5894.5s to 5911.5s (duration: 17.0s)
# Hypopnea: 5969.5s to 5982.0s (duration: 12.5s)
# ObstructiveApnea: 6607.0s to 6627.5s (duration: 20.5s)
# Hypopnea: 13414.5s to 13434.5s (duration: 20.0s)
# Hypopnea: 13760.5s to 13776.5s (duration: 16.0s)
#    📋 patient_24: Found 46 apnea events
#    🎵 patient_24: Processing EDF 1/4 - 00001640-100507[001].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001629-100507[003].edf: 100 frames processed...
#       🔄 00001615-100507[004].edf: 200 frames processed...
#       🔄 00001631-100507[001].edf: 100 frames processed...
#       ✅ 00001615-100507[004].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_21: Processing EDF 5/8 - 00001615-100507[005].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001640-100507[001].edf: 100 frames processed...
#       🔄 00001629-100507[003].edf: 200 frames processed...
#       ✅ 00001629-100507[003].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_22: Processing EDF 4/8 - 00001629-100507[004].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001631-100507[001].edf: 200 frames processed...
#       🔄 00001615-100507[005].edf: 100 frames processed...
#       ✅ 00001631-100507[001].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_23: Processing EDF 2/7 - 00001631-100507[002].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001640-100507[001].edf: 200 frames processed...
#       ✅ 00001640-100507[001].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_24: Processing EDF 2/4 - 00001640-100507[002].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001629-100507[004].edf: 100 frames processed...
#       🔄 00001615-100507[005].edf: 200 frames processed...
#       🔄 00001631-100507[002].edf: 100 frames processed...
#       ✅ 00001615-100507[005].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_21: Processing EDF 6/8 - 00001615-100507[006].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001640-100507[002].edf: 100 frames processed...
#       🔄 00001629-100507[004].edf: 200 frames processed...
#       ✅ 00001629-100507[004].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_22: Processing EDF 5/8 - 00001629-100507[005].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001631-100507[002].edf: 200 frames processed...
#       🔄 00001615-100507[006].edf: 100 frames processed...
#       ✅ 00001631-100507[002].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_23: Processing EDF 3/7 - 00001631-100507[003].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001640-100507[002].edf: 200 frames processed...
#       ✅ 00001640-100507[002].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_24: Processing EDF 3/4 - 00001640-100507[003].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001629-100507[005].edf: 100 frames processed...
#       🔄 00001615-100507[006].edf: 200 frames processed...
#       🔄 00001631-100507[003].edf: 100 frames processed...
#       ✅ 00001615-100507[006].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_21: Processing EDF 7/8 - 00001615-100507[007].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001640-100507[003].edf: 100 frames processed...
#       🔄 00001629-100507[005].edf: 200 frames processed...
#       ✅ 00001629-100507[005].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_22: Processing EDF 6/8 - 00001629-100507[006].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001631-100507[003].edf: 200 frames processed...
#       🔄 00001615-100507[007].edf: 100 frames processed...
#       ✅ 00001631-100507[003].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_23: Processing EDF 4/7 - 00001631-100507[004].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001640-100507[003].edf: 200 frames processed...
#       ✅ 00001640-100507[003].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_24: Processing EDF 4/4 - 00001640-100507[004].edf
#       ⏱️  Duration: 55.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001629-100507[006].edf: 100 frames processed...
#       🔄 00001615-100507[007].edf: 200 frames processed...
#       🔄 00001631-100507[004].edf: 100 frames processed...
#       ✅ 00001615-100507[007].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_21: Processing EDF 8/8 - 00001615-100507[008].edf
#       ⏱️  Duration: 17.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001640-100507[004].edf: 100 frames processed...
#       🔄 00001629-100507[006].edf: 200 frames processed...
#       ✅ 00001615-100507[008].edf: 66 frames extracted (downsampled to 16000 Hz)
# ✅ patient_21: 1739 total frames, 1006 apnea (2089.7s)
# 🎯 Progress: 22/25 completed (patient_21) - 1739 frames
#       ✅ 00001629-100507[006].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_22: Processing EDF 7/8 - 00001629-100507[007].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001631-100507[004].edf: 200 frames processed...
#       ✅ 00001631-100507[004].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_23: Processing EDF 5/7 - 00001631-100507[005].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001640-100507[004].edf: 200 frames processed...
#       ✅ 00001640-100507[004].edf: 218 frames extracted (downsampled to 16000 Hz)
# ✅ patient_24: 935 total frames, 111 apnea (1107.3s)
# 🎯 Progress: 23/25 completed (patient_24) - 935 frames
#       🔄 00001629-100507[007].edf: 100 frames processed...
#       🔄 00001631-100507[005].edf: 100 frames processed...
#       🔄 00001629-100507[007].edf: 200 frames processed...
#       ✅ 00001629-100507[007].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_22: Processing EDF 8/8 - 00001629-100507[008].edf
#       ⏱️  Duration: 26.8 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001631-100507[005].edf: 200 frames processed...
#       ✅ 00001631-100507[005].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_23: Processing EDF 6/7 - 00001631-100507[006].edf
#       ⏱️  Duration: 60.0 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001629-100507[008].edf: 100 frames processed...
#       ✅ 00001629-100507[008].edf: 106 frames extracted (downsampled to 16000 Hz)
# ✅ patient_22: 1779 total frames, 699 apnea (2040.5s)
# 🎯 Progress: 24/25 completed (patient_22) - 1779 frames
#       🔄 00001631-100507[006].edf: 100 frames processed...
#       🔄 00001631-100507[006].edf: 200 frames processed...
#       ✅ 00001631-100507[006].edf: 239 frames extracted (downsampled to 16000 Hz)
#    🎵 patient_23: Processing EDF 7/7 - 00001631-100507[007].edf
#       ⏱️  Duration: 44.5 min, Original SR: 48000 Hz → Target: 16000 Hz
#       🔄 00001631-100507[007].edf: 100 frames processed...
#       ✅ 00001631-100507[007].edf: 176 frames extracted (downsampled to 16000 Hz)
# ✅ patient_23: 1610 total frames, 802 apnea (1618.0s)
# 🎯 Progress: 25/25 completed (patient_23) - 1610 frames
#
# ============================================================
# 🏁 THREADING PROCESSING COMPLETE!
# ⏱️  Total time: 8842.8 seconds (147.4 minutes)
# ✅ Completed: 25
# ❌ Failed: 0
# 📊 Total features: 28,937
#
# 📋 DATASET STATISTICS:
# 📄 File saved: ../data/datasets/final_local_dataset.csv
# 📊 Shape: (28937, 34)
# 👥 Unique patients: 24
# 🚨 Apnea frames: 16,561 (57.2%)
# 😴 Normal frames: 12,376 (42.8%)
# 🎯 Feature count: 27
#
# 👤 PER-PATIENT BREAKDOWN:
#    patient_03: 900 frames, 659 apnea (73.2%)
#    patient_01: 988 frames, 406 apnea (41.1%)
#    patient_02: 1052 frames, 327 apnea (31.1%)
#    patient_04: 1126 frames, 646 apnea (57.4%)
#    patient_05: 981 frames, 626 apnea (63.8%)
#    patient_07: 1816 frames, 1464 apnea (80.6%)
#    patient_06: 989 frames, 569 apnea (57.5%)
#    patient_11: 870 frames, 277 apnea (31.8%)
#    patient_08: 999 frames, 933 apnea (93.4%)
#    patient_10: 965 frames, 618 apnea (64.0%)
#    patient_09: 1290 frames, 331 apnea (25.7%)
#    patient_13: 727 frames, 616 apnea (84.7%)
#    patient_12: 950 frames, 439 apnea (46.2%)
#    patient_15: 871 frames, 820 apnea (94.1%)
#    patient_14: 1372 frames, 320 apnea (23.3%)
#    patient_16: 902 frames, 868 apnea (96.2%)
#    patient_17: 1389 frames, 804 apnea (57.9%)
#    patient_18: 1390 frames, 1053 apnea (75.8%)
#    patient_19: 1724 frames, 1090 apnea (63.2%)
#    patient_20: 1573 frames, 1077 apnea (68.5%)
#    patient_21: 1739 frames, 1006 apnea (57.8%)
#    patient_24: 935 frames, 111 apnea (11.9%)
#    patient_22: 1779 frames, 699 apnea (39.3%)
#    patient_23: 1610 frames, 802 apnea (49.8%)
#
# 📋 SAMPLE DATA:
#    patient_id                  edf_file  timestamp  frame_duration  \
# 0  patient_03  00001059-100507[001].edf        0.0            30.0
# 1  patient_03  00001059-100507[001].edf       15.0            30.0
# 2  patient_03  00001059-100507[001].edf       30.0            30.0
# 3  patient_03  00001059-100507[001].edf       45.0            30.0
# 4  patient_03  00001059-100507[001].edf       60.0            30.0
#
#    sample_rate  apnea_label  apnea_proportion  clean_rms  clean_zcr  \
# 0        16000            0               0.0   0.018781   0.008050
# 1        16000            0               0.0   0.018767   0.008185
# 2        16000            0               0.0   0.018809   0.008435
# 3        16000            0               0.0   0.018649   0.008540
# 4        16000            0               0.0   0.018534   0.008199
#
#    clean_centroid  ...  clean_mfcc_4_mean  clean_mfcc_4_std  \
# 0      435.135582  ...          21.632960          4.445221
# 1      440.681128  ...          21.104202          4.540534
# 2      449.300563  ...          21.552625          4.548734
# 3      452.054127  ...          22.138940          4.436375
# 4      437.184857  ...          21.533348          3.901955
#
#    clean_mfcc_5_mean  clean_mfcc_5_std  clean_mfcc_6_mean  clean_mfcc_6_std  \
# 0          13.640333          3.724264          15.770599          2.995790
# 1          13.673262          3.787712          15.310787          2.947097
# 2          13.442337          3.997437          15.125630          2.889535
# 3          13.571640          4.088285          15.281693          3.279922
# 4          13.999837          3.641444          15.277462          3.403390
#
#    clean_mfcc_7_mean  clean_mfcc_7_std  clean_mfcc_8_mean  clean_mfcc_8_std
# 0          10.324357          3.095657          17.298379          3.191640
# 1          10.299265          3.241248          17.258023          3.367288
# 2          10.229978          3.279603          17.272357          3.552718
# 3          10.070343          3.381759          17.062090          3.374816
# 4          10.074261          3.406345          17.092082          3.095848
#
# [5 rows x 34 columns]
#
# 🔗 TOP 5 FEATURE CORRELATIONS WITH APNEA:
#    clean_mfcc_8_mean: 0.268
#    clean_zcr_variability: 0.230
#    clean_mfcc_3_std: 0.197
#    clean_mfcc_8_std: 0.152
#    clean_mfcc_4_mean: 0.141
#
# 🎉 SUCCESS! Dataset ready for model training.
# 📁 Saved as: ../data/datasets/final_local_dataset.csv
# 🚀 Threading approach avoided Windows multiprocessing issues!
#
# Time finished: 2025-07-28 17:18:56
