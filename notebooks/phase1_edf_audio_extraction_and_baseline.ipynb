# %% [markdown]
# # Phase 1: EDF Audio Extraction and Baseline Establishment
#
# ## Research Goal
# Extract clean audio from EDF files and establish baseline performance for denoising evaluation pipeline.
#
# ## This Notebook:
# 1. **EDF to WAV Conversion**: Extract audio from clinical EDF files
# 2. **Baseline Model Testing**: Validate trained model on extracted audio
# 3. **Clean Audio Performance**: Establish clean audio baseline metrics
# 4. **Test Set Preparation**: Create standardized test set for noise experiments
#
# ## Output:
# - WAV files organized by patient for denoising pipeline
# - Baseline performance metrics (F1, sensitivity, specificity)
# - Feature extraction validation
# - Clean audio test set ready for Phase 2 noise injection
#
# ---

# %%
# Cell 1: Imports and Configuration
print("=== Phase 1: EDF Audio Extraction and Baseline Establishment ===")

import os
import time
import numpy as np
import pandas as pd
import librosa
import soundfile as sf
import mne
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Model loading for baseline testing
import joblib
from sklearn.metrics import classification_report, confusion_matrix, f1_score

# Add custom XML parser
import sys
sys.path.append('../src')

try:
    from working_with_xml import extract_apnea_events
    print("✅ XML parser imported successfully")
except Exception as e:
    print(f"❌ XML parser import failed: {e}")

# Configuration
PATIENT_DATA_DIR = "F:/Solo All In One Docs/Scidb Sleep Data"
AUDIO_OUTPUT_DIR = "F:/Solo All In One Docs/Scidb Sleep Data/processed"  # Where WAV files will be saved
MODEL_PATH = "../models/sleep_apnea_model.pkl"  # Trained model path

# Test patients (subset for Phase 1)
TEST_PATIENTS = ['patient_01', 'patient_02', 'patient_03','patient_04','patient_05','patient_06','patient_07','patient_08',
                 'patient_09','patient_10'] 

# Audio processing settings (same as training)
AUDIO_CHANNEL = 'Mic'
TARGET_SAMPLE_RATE = 16000  # 16kHz as used in training
FRAME_DURATION = 30.0  # 30-second windows
OVERLAP_RATIO = 0.5
APNEA_THRESHOLD = 0.1

print(f"\n📁 Patient data directory: {PATIENT_DATA_DIR}")
print(f"🎵 Audio output directory: {AUDIO_OUTPUT_DIR}")
print(f"🤖 Model path: {MODEL_PATH}")
print(f"👥 Test patients: {TEST_PATIENTS}")
print(f"🎯 Audio settings: {TARGET_SAMPLE_RATE}Hz, {FRAME_DURATION}s frames, {OVERLAP_RATIO} overlap")

# Create output directories
os.makedirs(AUDIO_OUTPUT_DIR, exist_ok=True)
print(f"✅ Directories created/verified")
# Out:
# === Phase 1: EDF Audio Extraction and Baseline Establishment ===
# ✅ XML parser imported successfully
#
# 📁 Patient data directory: F:/Solo All In One Docs/Scidb Sleep Data
# 🎵 Audio output directory: F:/Solo All In One Docs/Scidb Sleep Data/processed
# 🤖 Model path: ../models/sleep_apnea_model.pkl
# 👥 Test patients: ['patient_01', 'patient_02', 'patient_03', 'patient_04', 'patient_05', 'patient_06', 'patient_07', 'patient_08', 'patient_09', 'patient_10']
# 🎯 Audio settings: 16000Hz, 30.0s frames, 0.5 overlap
# ✅ Directories created/verified

# %%
# Cell 2: Feature Extraction Functions (Same as Training Pipeline)
def extract_comprehensive_features(audio_frame, sample_rate):
    """Extract the same 27 features used in training pipeline"""
    try:
        if len(audio_frame) == 0:
            return None
            
        # Basic acoustic features
        rms = float(librosa.feature.rms(y=audio_frame).mean())
        zcr = float(librosa.feature.zero_crossing_rate(y=audio_frame).mean())
        centroid = float(librosa.feature.spectral_centroid(y=audio_frame, sr=sample_rate).mean())
        bandwidth = float(librosa.feature.spectral_bandwidth(y=audio_frame, sr=sample_rate).mean())
        rolloff = float(librosa.feature.spectral_rolloff(y=audio_frame, sr=sample_rate).mean())
        
        # MFCCs (first 8 coefficients)
        mfccs = librosa.feature.mfcc(y=audio_frame, sr=sample_rate, n_mfcc=8)
        mfcc_means = mfccs.mean(axis=1)
        mfcc_stds = mfccs.std(axis=1)
        
        # Temporal features for breathing patterns (5-second windows)
        window_size = int(5 * sample_rate)  # 5 seconds
        num_windows = len(audio_frame) // window_size
        
        if num_windows >= 2:
            rms_windows = []
            zcr_windows = []
            
            for i in range(num_windows):
                start_idx = i * window_size
                end_idx = start_idx + window_size
                window = audio_frame[start_idx:end_idx]
                
                rms_windows.append(librosa.feature.rms(y=window).mean())
                zcr_windows.append(librosa.feature.zero_crossing_rate(y=window).mean())
            
            rms_variability = float(np.std(rms_windows))
            zcr_variability = float(np.std(zcr_windows))
            breathing_regularity = float(1.0 / (1.0 + rms_variability))  # Higher = more regular
        else:
            rms_variability = 0.0
            zcr_variability = 0.0
            breathing_regularity = 0.5
        
        # Silence detection
        silence_threshold = np.percentile(np.abs(audio_frame), 20)  # Bottom 20% as silence
        silence_mask = np.abs(audio_frame) < silence_threshold
        silence_ratio = float(np.mean(silence_mask))
        
        # Breathing pause detection (continuous silence periods)
        silence_changes = np.diff(silence_mask.astype(int))
        pause_starts = np.where(silence_changes == 1)[0]
        pause_ends = np.where(silence_changes == -1)[0]
        
        if len(pause_starts) > 0 and len(pause_ends) > 0:
            if len(pause_ends) < len(pause_starts):
                pause_ends = np.append(pause_ends, len(audio_frame))
            pause_durations = (pause_ends[:len(pause_starts)] - pause_starts) / sample_rate
            avg_pause_duration = float(np.mean(pause_durations))
            max_pause_duration = float(np.max(pause_durations))
        else:
            avg_pause_duration = 0.0
            max_pause_duration = 0.0
        
        # Combine all features (same structure as training)
        features = {
            'clean_rms': rms,
            'clean_zcr': zcr,
            'clean_centroid': centroid,
            'clean_bandwidth': bandwidth,
            'clean_rolloff': rolloff,
            'clean_rms_variability': rms_variability,
            'clean_zcr_variability': zcr_variability,
            'clean_breathing_regularity': breathing_regularity,
            'clean_silence_ratio': silence_ratio,
            'clean_avg_pause_duration': avg_pause_duration,
            'clean_max_pause_duration': max_pause_duration
        }
        
        # Add MFCCs
        for i, (mean_val, std_val) in enumerate(zip(mfcc_means, mfcc_stds), 1):
            features[f'clean_mfcc_{i}_mean'] = float(mean_val)
            features[f'clean_mfcc_{i}_std'] = float(std_val)
        
        return features
        
    except Exception as e:
        print(f"   ⚠️  Feature extraction error: {e}")
        return None

def get_apnea_label(timestamp, duration, apnea_events, threshold=0.1):
    """Calculate apnea label based on overlap with events (same as training)"""
    try:
        frame_end = timestamp + duration
        apnea_seconds = 0
        
        for start, end in apnea_events:
            overlap_start = max(timestamp, start)
            overlap_end = min(frame_end, end)
            if overlap_start < overlap_end:
                apnea_seconds += (overlap_end - overlap_start)
        
        proportion = apnea_seconds / duration
        label = 1 if proportion > threshold else 0
        return label, proportion
    except:
        return 0, 0.0

print("✅ Feature extraction functions defined (identical to training pipeline)")
# Out:
# ✅ Feature extraction functions defined (identical to training pipeline)

# %%
# Cell 3: EDF to WAV Conversion Function
def extract_audio_from_patient(patient_id, data_dir, output_dir):
    """Extract audio from all EDF files for a patient and save as WAV files"""
    
    print(f"🎵 Starting audio extraction for {patient_id}...")
    
    try:
        # Check patient directory
        patient_dir = os.path.join(data_dir, patient_id)
        if not os.path.exists(patient_dir):
            print(f"❌ {patient_id}: Directory not found: {patient_dir}")
            return None
        
        # Find EDF and RML files
        edf_files = sorted([f for f in os.listdir(patient_dir) if f.endswith('.edf')])
        rml_files = [f for f in os.listdir(patient_dir) if f.endswith('.rml')]
        
        if not edf_files or not rml_files:
            print(f"❌ {patient_id}: Missing EDF ({len(edf_files)}) or RML ({len(rml_files)}) files")
            return None
        
        print(f"   📁 {patient_id}: Found {len(edf_files)} EDF and {len(rml_files)} RML files")
        
        # Load apnea events
        rml_path = os.path.join(patient_dir, rml_files[0])
        apnea_data = extract_apnea_events(rml_path, output_csv=None)
        apnea_events = [(float(start), float(end)) for event_type, start, end in apnea_data]
        print(f"   📋 {patient_id}: Found {len(apnea_events)} apnea events")
        
        # Create patient audio output directory
        patient_audio_dir = os.path.join(output_dir, f"{patient_id}_wav")
        os.makedirs(patient_audio_dir, exist_ok=True)
        
        # Process each EDF file
        extracted_data = []
        total_wav_files = 0
        
        for edf_idx, edf_file in enumerate(edf_files, 1):
            print(f"   🎧 {patient_id}: Processing EDF {edf_idx}/{len(edf_files)} - {edf_file}")
            
            try:
                edf_path = os.path.join(patient_dir, edf_file)
                raw = mne.io.read_raw_edf(edf_path, preload=False, verbose=False)
                
                if AUDIO_CHANNEL not in raw.ch_names:
                    print(f"   ⚠️  {patient_id}: No {AUDIO_CHANNEL} channel in {edf_file}, skipping")
                    continue
                
                raw.pick_channels([AUDIO_CHANNEL])
                original_sample_rate = int(raw.info['sfreq'])
                duration_minutes = raw.n_times / original_sample_rate / 60
                print(f"      ⏱️  Duration: {duration_minutes:.1f} min, SR: {original_sample_rate} Hz → {TARGET_SAMPLE_RATE} Hz")
                
                # Frame parameters
                original_frame_samples = int(FRAME_DURATION * original_sample_rate)
                original_step_samples = int(original_frame_samples * (1 - OVERLAP_RATIO))
                
                # Time offset for multi-EDF
                time_offset = (edf_idx - 1) * 60 * 60  # Each EDF = 1 hour
                
                # Extract and save WAV files
                edf_wav_count = 0
                
                for frame_start in range(0, raw.n_times - original_frame_samples + 1, original_step_samples):
                    frame_end = frame_start + original_frame_samples
                    timestamp = (frame_start / original_sample_rate) + time_offset
                    
                    # Load audio frame
                    try:
                        audio_frame, _ = raw[:, frame_start:frame_end]
                        audio_frame = audio_frame.flatten()
                        
                        # Downsample to target sample rate
                        if original_sample_rate != TARGET_SAMPLE_RATE:
                            audio_frame = librosa.resample(audio_frame, 
                                                         orig_sr=original_sample_rate, 
                                                         target_sr=TARGET_SAMPLE_RATE)
                        
                        # Create WAV filename with timestamp
                        edf_base = os.path.splitext(edf_file)[0]
                        wav_filename = f"{patient_id}_{edf_base}_frame_{int(timestamp):06d}.wav"
                        wav_path = os.path.join(patient_audio_dir, wav_filename)
                        
                        # Save as WAV file
                        sf.write(wav_path, audio_frame, TARGET_SAMPLE_RATE)
                        
                        # Get apnea label for metadata
                        apnea_label, apnea_proportion = get_apnea_label(timestamp, FRAME_DURATION, apnea_events, APNEA_THRESHOLD)
                        
                        # Store metadata
                        metadata = {
                            'patient_id': patient_id,
                            'edf_file': edf_file,
                            'wav_file': wav_filename,
                            'wav_path': wav_path,
                            'timestamp': float(timestamp),
                            'frame_duration': FRAME_DURATION,
                            'sample_rate': TARGET_SAMPLE_RATE,
                            'apnea_label': int(apnea_label),
                            'apnea_proportion': float(apnea_proportion)
                        }
                        
                        extracted_data.append(metadata)
                        edf_wav_count += 1
                        total_wav_files += 1
                        
                    except Exception as e:
                        print(f"      ⚠️  Frame extraction failed: {e}")
                        continue
                
                print(f"      ✅ {edf_file}: {edf_wav_count} WAV files created")
                del raw  # Free memory
                
            except Exception as e:
                print(f"   ❌ {patient_id}: Failed processing {edf_file}: {e}")
                continue
        
        print(f"✅ {patient_id}: {total_wav_files} total WAV files extracted")
        return extracted_data
        
    except Exception as e:
        print(f"❌ {patient_id}: Critical error: {e}")
        return None

print("✅ EDF to WAV conversion function defined")
# Out:
# ✅ EDF to WAV conversion function defined

# %%
# Cell 4: Execute Audio Extraction
print("🎵 STARTING EDF TO WAV AUDIO EXTRACTION")
print(f"Time started: {time.strftime('%Y-%m-%d %H:%M:%S')}")
print(f"{'='*60}")

start_time = time.time()
all_audio_metadata = []

# Extract audio for each test patient
for patient_id in TEST_PATIENTS:
    patient_metadata = extract_audio_from_patient(patient_id, PATIENT_DATA_DIR, AUDIO_OUTPUT_DIR)
    
    if patient_metadata:
        all_audio_metadata.extend(patient_metadata)
        print(f"🎯 Progress: {patient_id} completed - {len(patient_metadata)} WAV files")
    else:
        print(f"❌ {patient_id}: Audio extraction failed")
    
    print(f"{'-'*40}")

total_time = time.time() - start_time

# Summary
print(f"\n{'='*60}")
print(f"🏁 AUDIO EXTRACTION COMPLETE!")
print(f"⏱️  Total time: {total_time:.1f} seconds ({total_time/60:.1f} minutes)")
print(f"🎵 Total WAV files: {len(all_audio_metadata):,}")

if all_audio_metadata:
    # Convert to DataFrame and save metadata
    audio_df = pd.DataFrame(all_audio_metadata)
    metadata_path = os.path.join(AUDIO_OUTPUT_DIR, "audio_metadata.csv")
    audio_df.to_csv(metadata_path, index=False)
    
    # Statistics
    apnea_count = audio_df['apnea_label'].sum()
    apnea_rate = audio_df['apnea_label'].mean() * 100
    
    print(f"\n📋 AUDIO EXTRACTION STATISTICS:")
    print(f"📄 Metadata saved: {metadata_path}")
    print(f"📊 Total files: {len(audio_df):,}")
    print(f"👥 Patients: {audio_df['patient_id'].nunique()}")
    print(f"🚨 Apnea files: {apnea_count:,} ({apnea_rate:.1f}%)")
    print(f"😴 Normal files: {len(audio_df) - apnea_count:,} ({100-apnea_rate:.1f}%)")
    
    # Per-patient breakdown
    print(f"\n👤 PER-PATIENT WAV FILES:")
    patient_stats = audio_df.groupby('patient_id').agg({
        'apnea_label': ['count', 'sum', 'mean']
    }).round(3)
    
    for patient in audio_df['patient_id'].unique():
        count = patient_stats.loc[patient, ('apnea_label', 'count')]
        apnea = patient_stats.loc[patient, ('apnea_label', 'sum')]
        rate = patient_stats.loc[patient, ('apnea_label', 'mean')] * 100
        print(f"   {patient}: {count} files, {apnea} apnea ({rate:.1f}%)")
    
    print(f"\n🎉 SUCCESS! Clean audio extracted and ready for denoising pipeline.")
    
else:
    print(f"❌ No audio files extracted. Check error messages above.")

print(f"\nTime finished: {time.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# 🎵 STARTING EDF TO WAV AUDIO EXTRACTION
# Time started: 2025-07-30 01:24:59
# ============================================================
# 🎵 Starting audio extraction for patient_01...
#    📁 patient_01: Found 5 EDF and 1 RML files
# Hypopnea: 4329.0s to 4340.0s (duration: 11.0s)
# Hypopnea: 4354.5s to 4368.5s (duration: 14.0s)
# Hypopnea: 4389.5s to 4401.0s (duration: 11.5s)
# Hypopnea: 4434.0s to 4446.0s (duration: 12.0s)
# ObstructiveApnea: 4657.5s to 4670.5s (duration: 13.0s)
# Hypopnea: 4897.5s to 4910.0s (duration: 12.5s)
# Hypopnea: 4936.5s to 4948.0s (duration: 11.5s)
# Hypopnea: 4995.5s to 5008.0s (duration: 12.5s)
# ObstructiveApnea: 5202.5s to 5215.0s (duration: 12.5s)
# Hypopnea: 5279.5s to 5292.0s (duration: 12.5s)
# Hypopnea: 5445.0s to 5460.0s (duration: 15.0s)
# Hypopnea: 5543.0s to 5558.0s (duration: 15.0s)
# ObstructiveApnea: 5634.0s to 5649.0s (duration: 15.0s)
# Hypopnea: 5713.5s to 5731.0s (duration: 17.5s)
# ObstructiveApnea: 7777.0s to 7788.0s (duration: 11.0s)
# ObstructiveApnea: 7856.5s to 7866.5s (duration: 10.0s)
# ObstructiveApnea: 7877.5s to 7890.0s (duration: 12.5s)
# ObstructiveApnea: 7922.5s to 7933.0s (duration: 10.5s)
# Hypopnea: 7969.5s to 7980.5s (duration: 11.0s)
# Hypopnea: 8004.5s to 8017.5s (duration: 13.0s)
# ObstructiveApnea: 8044.0s to 8057.5s (duration: 13.5s)
# ObstructiveApnea: 8088.5s to 8104.5s (duration: 16.0s)
# Hypopnea: 8138.0s to 8169.0s (duration: 31.0s)
# ObstructiveApnea: 8204.5s to 8217.0s (duration: 12.5s)
# Hypopnea: 8256.5s to 8273.0s (duration: 16.5s)
# Hypopnea: 8331.5s to 8358.0s (duration: 26.5s)
# ObstructiveApnea: 8406.0s to 8417.0s (duration: 11.0s)
# ObstructiveApnea: 8435.0s to 8454.5s (duration: 19.5s)
# Hypopnea: 9189.0s to 9200.0s (duration: 11.0s)
# ObstructiveApnea: 9212.5s to 9222.5s (duration: 10.0s)
# ObstructiveApnea: 9254.0s to 9264.5s (duration: 10.5s)
# ObstructiveApnea: 9283.5s to 9296.0s (duration: 12.5s)
# Hypopnea: 9422.0s to 9436.0s (duration: 14.0s)
# ObstructiveApnea: 9461.0s to 9472.0s (duration: 11.0s)
# ObstructiveApnea: 9489.0s to 9501.5s (duration: 12.5s)
# ObstructiveApnea: 9517.0s to 9529.0s (duration: 12.0s)
# ObstructiveApnea: 9562.0s to 9573.0s (duration: 11.0s)
# ObstructiveApnea: 9606.5s to 9620.5s (duration: 14.0s)
# ObstructiveApnea: 9640.5s to 9653.0s (duration: 12.5s)
# CentralApnea: 9681.5s to 9694.0s (duration: 12.5s)
# Hypopnea: 9711.5s to 9723.0s (duration: 11.5s)
# Hypopnea: 9759.5s to 9773.0s (duration: 13.5s)
# CentralApnea: 9797.5s to 9808.5s (duration: 11.0s)
# ObstructiveApnea: 9826.5s to 9841.0s (duration: 14.5s)
# CentralApnea: 9865.0s to 9882.5s (duration: 17.5s)
# Hypopnea: 9917.0s to 9933.0s (duration: 16.0s)
# ObstructiveApnea: 9954.5s to 9967.0s (duration: 12.5s)
# MixedApnea: 10000.5s to 10012.0s (duration: 11.5s)
# MixedApnea: 10033.5s to 10050.0s (duration: 16.5s)
# CentralApnea: 10069.5s to 10079.5s (duration: 10.0s)
# CentralApnea: 10087.5s to 10097.5s (duration: 10.0s)
# ObstructiveApnea: 10112.0s to 10127.0s (duration: 15.0s)
# ObstructiveApnea: 10170.5s to 10180.5s (duration: 10.0s)
# ObstructiveApnea: 10196.5s to 10207.0s (duration: 10.5s)
# CentralApnea: 10223.5s to 10233.5s (duration: 10.0s)
# Hypopnea: 10295.5s to 10309.0s (duration: 13.5s)
# Hypopnea: 10323.5s to 10333.5s (duration: 10.0s)
# ObstructiveApnea: 10347.0s to 10357.5s (duration: 10.5s)
# Hypopnea: 10380.5s to 10392.5s (duration: 12.0s)
# ObstructiveApnea: 10404.0s to 10415.5s (duration: 11.5s)
# ObstructiveApnea: 10432.5s to 10448.5s (duration: 16.0s)
# ObstructiveApnea: 10479.5s to 10491.0s (duration: 11.5s)
# MixedApnea: 10520.0s to 10532.0s (duration: 12.0s)
# MixedApnea: 10541.5s to 10552.0s (duration: 10.5s)
# MixedApnea: 10566.0s to 10577.5s (duration: 11.5s)
# MixedApnea: 10595.5s to 10610.0s (duration: 14.5s)
# ObstructiveApnea: 10638.5s to 10659.5s (duration: 21.0s)
# ObstructiveApnea: 10685.5s to 10701.0s (duration: 15.5s)
# ObstructiveApnea: 10729.5s to 10740.5s (duration: 11.0s)
# ObstructiveApnea: 10756.0s to 10770.5s (duration: 14.5s)
# MixedApnea: 10864.0s to 10875.0s (duration: 11.0s)
# ObstructiveApnea: 10894.0s to 10905.5s (duration: 11.5s)
# CentralApnea: 10926.0s to 10937.0s (duration: 11.0s)
# MixedApnea: 16216.0s to 16237.0s (duration: 21.0s)
# ObstructiveApnea: 16252.0s to 16275.5s (duration: 23.5s)
# MixedApnea: 16294.0s to 16318.5s (duration: 24.5s)
# ObstructiveApnea: 16338.5s to 16350.0s (duration: 11.5s)
# ObstructiveApnea: 16368.5s to 16390.0s (duration: 21.5s)
# ObstructiveApnea: 16411.0s to 16427.0s (duration: 16.0s)
# Hypopnea: 16455.0s to 16467.0s (duration: 12.0s)
# ObstructiveApnea: 16649.0s to 16662.5s (duration: 13.5s)
# ObstructiveApnea: 16681.5s to 16697.0s (duration: 15.5s)
# ObstructiveApnea: 16710.5s to 16722.5s (duration: 12.0s)
# ObstructiveApnea: 16742.0s to 16764.0s (duration: 22.0s)
# ObstructiveApnea: 16786.5s to 16799.5s (duration: 13.0s)
# ObstructiveApnea: 16815.0s to 16831.0s (duration: 16.0s)
# ObstructiveApnea: 16844.0s to 16858.5s (duration: 14.5s)
# ObstructiveApnea: 16880.5s to 16899.5s (duration: 19.0s)
# ObstructiveApnea: 16920.5s to 16938.0s (duration: 17.5s)
# ObstructiveApnea: 16958.5s to 16972.5s (duration: 14.0s)
# ObstructiveApnea: 16998.0s to 17019.0s (duration: 21.0s)
# ObstructiveApnea: 17042.5s to 17076.0s (duration: 33.5s)
# ObstructiveApnea: 17102.0s to 17121.5s (duration: 19.5s)
# ObstructiveApnea: 17140.5s to 17164.5s (duration: 24.0s)
# ObstructiveApnea: 17186.0s to 17204.5s (duration: 18.5s)
# ObstructiveApnea: 17228.0s to 17248.5s (duration: 20.5s)
# ObstructiveApnea: 17273.5s to 17296.0s (duration: 22.5s)
# ObstructiveApnea: 17321.5s to 17338.0s (duration: 16.5s)
# ObstructiveApnea: 17358.0s to 17373.5s (duration: 15.5s)
# ObstructiveApnea: 17400.0s to 17416.0s (duration: 16.0s)
# ObstructiveApnea: 17427.0s to 17441.0s (duration: 14.0s)
# ObstructiveApnea: 17461.5s to 17485.0s (duration: 23.5s)
# ObstructiveApnea: 17501.0s to 17522.5s (duration: 21.5s)
# ObstructiveApnea: 17544.0s to 17563.5s (duration: 19.5s)
#    📋 patient_01: Found 239 apnea events
#    🎧 patient_01: Processing EDF 1/5 - 00001206-100507[001].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001206-100507[001].edf: 239 WAV files created
#    🎧 patient_01: Processing EDF 2/5 - 00001206-100507[002].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001206-100507[002].edf: 239 WAV files created
#    🎧 patient_01: Processing EDF 3/5 - 00001206-100507[003].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001206-100507[003].edf: 239 WAV files created
#    🎧 patient_01: Processing EDF 4/5 - 00001206-100507[004].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001206-100507[004].edf: 239 WAV files created
#    🎧 patient_01: Processing EDF 5/5 - 00001206-100507[005].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 53.3 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001206-100507[005].edf: 212 WAV files created
# ✅ patient_01: 1168 total WAV files extracted
# 🎯 Progress: patient_01 completed - 1168 WAV files
# ----------------------------------------
# 🎵 Starting audio extraction for patient_02...
#    📁 patient_02: Found 7 EDF and 1 RML files
# Hypopnea: 11469.0s to 11480.0s (duration: 11.0s)
# Hypopnea: 11509.5s to 11519.5s (duration: 10.0s)
# Hypopnea: 11572.5s to 11585.0s (duration: 12.5s)
# Hypopnea: 11648.5s to 11659.5s (duration: 11.0s)
# Hypopnea: 11683.5s to 11696.5s (duration: 13.0s)
# ObstructiveApnea: 11831.5s to 11851.0s (duration: 19.5s)
# ObstructiveApnea: 12036.5s to 12049.0s (duration: 12.5s)
# Hypopnea: 12093.0s to 12108.0s (duration: 15.0s)
# ObstructiveApnea: 12164.0s to 12175.5s (duration: 11.5s)
# ObstructiveApnea: 12187.0s to 12205.0s (duration: 18.0s)
# Hypopnea: 12231.0s to 12243.0s (duration: 12.0s)
# ObstructiveApnea: 12294.5s to 12308.0s (duration: 13.5s)
# Hypopnea: 12321.0s to 12335.0s (duration: 14.0s)
# ObstructiveApnea: 12388.0s to 12402.0s (duration: 14.0s)
# ObstructiveApnea: 12419.5s to 12436.0s (duration: 16.5s)
# ObstructiveApnea: 12490.0s to 12512.5s (duration: 22.5s)
# ObstructiveApnea: 12594.0s to 12608.5s (duration: 14.5s)
# ObstructiveApnea: 12702.5s to 12719.5s (duration: 17.0s)
# ObstructiveApnea: 12830.0s to 12844.0s (duration: 14.0s)
# ObstructiveApnea: 12929.0s to 12951.0s (duration: 22.0s)
# ObstructiveApnea: 12983.5s to 12996.0s (duration: 12.5s)
# Hypopnea: 13032.0s to 13047.0s (duration: 15.0s)
# Hypopnea: 13074.0s to 13092.5s (duration: 18.5s)
# Hypopnea: 13117.5s to 13158.0s (duration: 40.5s)
# Hypopnea: 13184.5s to 13203.5s (duration: 19.0s)
# ObstructiveApnea: 13233.0s to 13248.0s (duration: 15.0s)
# ObstructiveApnea: 13264.5s to 13284.5s (duration: 20.0s)
# Hypopnea: 13309.0s to 13325.0s (duration: 16.0s)
# ObstructiveApnea: 13394.5s to 13415.5s (duration: 21.0s)
# ObstructiveApnea: 13471.5s to 13490.0s (duration: 18.5s)
# ObstructiveApnea: 13614.5s to 13628.0s (duration: 13.5s)
# ObstructiveApnea: 13698.0s to 13711.5s (duration: 13.5s)
# ObstructiveApnea: 13814.5s to 13829.5s (duration: 15.0s)
# Hypopnea: 13862.0s to 13875.0s (duration: 13.0s)
# ObstructiveApnea: 13949.5s to 13967.0s (duration: 17.5s)
# ObstructiveApnea: 14012.0s to 14022.0s (duration: 10.0s)
# ObstructiveApnea: 14093.5s to 14105.0s (duration: 11.5s)
# ObstructiveApnea: 14141.5s to 14154.0s (duration: 12.5s)
# ObstructiveApnea: 14187.0s to 14198.5s (duration: 11.5s)
# Hypopnea: 14274.0s to 14287.0s (duration: 13.0s)
# ObstructiveApnea: 21373.0s to 21410.0s (duration: 37.0s)
# MixedApnea: 21442.0s to 21454.5s (duration: 12.5s)
# ObstructiveApnea: 21504.0s to 21539.0s (duration: 35.0s)
# Hypopnea: 21573.0s to 21592.0s (duration: 19.0s)
# ObstructiveApnea: 21664.0s to 21676.5s (duration: 12.5s)
# ObstructiveApnea: 21749.0s to 21780.0s (duration: 31.0s)
# Hypopnea: 21796.0s to 21821.0s (duration: 25.0s)
# ObstructiveApnea: 21887.0s to 21908.0s (duration: 21.0s)
# ObstructiveApnea: 21928.0s to 21938.5s (duration: 10.5s)
# Hypopnea: 21966.5s to 21998.5s (duration: 32.0s)
# Hypopnea: 22034.0s to 22065.5s (duration: 31.5s)
# ObstructiveApnea: 22105.0s to 22133.5s (duration: 28.5s)
# ObstructiveApnea: 22144.5s to 22157.0s (duration: 12.5s)
# ObstructiveApnea: 22183.5s to 22219.0s (duration: 35.5s)
# ObstructiveApnea: 22247.5s to 22283.5s (duration: 36.0s)
# ObstructiveApnea: 22316.5s to 22364.5s (duration: 48.0s)
# ObstructiveApnea: 22392.0s to 22428.0s (duration: 36.0s)
# ObstructiveApnea: 22471.5s to 22500.0s (duration: 28.5s)
# ObstructiveApnea: 22556.0s to 22588.5s (duration: 32.5s)
# ObstructiveApnea: 22645.5s to 22719.5s (duration: 74.0s)
# Hypopnea: 22768.0s to 22798.5s (duration: 30.5s)
# ObstructiveApnea: 22888.5s to 22912.0s (duration: 23.5s)
# Hypopnea: 22967.0s to 22987.5s (duration: 20.5s)
# Hypopnea: 23018.5s to 23039.0s (duration: 20.5s)
# Hypopnea: 23088.5s to 23131.0s (duration: 42.5s)
# ObstructiveApnea: 23189.0s to 23238.0s (duration: 49.0s)
# Hypopnea: 23303.5s to 23342.0s (duration: 38.5s)
# ObstructiveApnea: 23559.5s to 23576.5s (duration: 17.0s)
# Hypopnea: 23615.0s to 23638.5s (duration: 23.5s)
#    📋 patient_02: Found 158 apnea events
#    🎧 patient_02: Processing EDF 1/7 - 00001210-100507[001].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001210-100507[001].edf: 239 WAV files created
#    🎧 patient_02: Processing EDF 2/7 - 00001210-100507[002].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001210-100507[002].edf: 239 WAV files created
#    🎧 patient_02: Processing EDF 3/7 - 00001210-100507[003].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001210-100507[003].edf: 239 WAV files created
#    🎧 patient_02: Processing EDF 4/7 - 00001210-100507[004].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001210-100507[004].edf: 239 WAV files created
#    🎧 patient_02: Processing EDF 5/7 - 00001210-100507[005].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001210-100507[005].edf: 239 WAV files created
#    🎧 patient_02: Processing EDF 6/7 - 00001210-100507[006].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001210-100507[006].edf: 239 WAV files created
#    🎧 patient_02: Processing EDF 7/7 - 00001210-100507[007].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 34.5 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001210-100507[007].edf: 137 WAV files created
# ✅ patient_02: 1571 total WAV files extracted
# 🎯 Progress: patient_02 completed - 1571 WAV files
# ----------------------------------------
# 🎵 Starting audio extraction for patient_03...
#    📁 patient_03: Found 5 EDF and 1 RML files
# ObstructiveApnea: 81.5s to 93.5s (duration: 12.0s)
# ObstructiveApnea: 117.0s to 129.5s (duration: 12.5s)
# ObstructiveApnea: 142.5s to 163.0s (duration: 20.5s)
# ObstructiveApnea: 176.0s to 190.5s (duration: 14.5s)
# ObstructiveApnea: 204.0s to 221.0s (duration: 17.0s)
# Hypopnea: 250.5s to 266.0s (duration: 15.5s)
# ObstructiveApnea: 301.0s to 311.5s (duration: 10.5s)
# ObstructiveApnea: 323.5s to 334.5s (duration: 11.0s)
# Hypopnea: 376.5s to 388.5s (duration: 12.0s)
# Hypopnea: 414.5s to 427.0s (duration: 12.5s)
# Hypopnea: 614.0s to 625.0s (duration: 11.0s)
# ObstructiveApnea: 638.5s to 649.0s (duration: 10.5s)
# ObstructiveApnea: 663.0s to 676.5s (duration: 13.5s)
# ObstructiveApnea: 704.5s to 715.5s (duration: 11.0s)
# ObstructiveApnea: 728.5s to 739.0s (duration: 10.5s)
# ObstructiveApnea: 754.5s to 766.5s (duration: 12.0s)
# ObstructiveApnea: 791.0s to 805.0s (duration: 14.0s)
# ObstructiveApnea: 819.0s to 832.0s (duration: 13.0s)
# ObstructiveApnea: 840.0s to 850.5s (duration: 10.5s)
# ObstructiveApnea: 872.0s to 886.5s (duration: 14.5s)
# ObstructiveApnea: 908.0s to 924.0s (duration: 16.0s)
# ObstructiveApnea: 935.0s to 946.0s (duration: 11.0s)
# ObstructiveApnea: 958.0s to 968.5s (duration: 10.5s)
# Hypopnea: 981.5s to 994.5s (duration: 13.0s)
# ObstructiveApnea: 1010.0s to 1027.0s (duration: 17.0s)
# ObstructiveApnea: 1043.5s to 1063.0s (duration: 19.5s)
# ObstructiveApnea: 1082.0s to 1094.0s (duration: 12.0s)
# ObstructiveApnea: 1105.0s to 1115.5s (duration: 10.5s)
# ObstructiveApnea: 1131.5s to 1142.0s (duration: 10.5s)
# ObstructiveApnea: 1156.0s to 1171.5s (duration: 15.5s)
# ObstructiveApnea: 1204.0s to 1215.0s (duration: 11.0s)
# ObstructiveApnea: 1236.5s to 1251.0s (duration: 14.5s)
# ObstructiveApnea: 1267.0s to 1283.0s (duration: 16.0s)
# ObstructiveApnea: 1297.5s to 1316.5s (duration: 19.0s)
# ObstructiveApnea: 1338.0s to 1361.0s (duration: 23.0s)
# MixedApnea: 1395.5s to 1406.0s (duration: 10.5s)
# MixedApnea: 1422.0s to 1440.0s (duration: 18.0s)
# ObstructiveApnea: 10488.0s to 10504.5s (duration: 16.5s)
# ObstructiveApnea: 10526.0s to 10544.0s (duration: 18.0s)
# Hypopnea: 10555.0s to 10573.5s (duration: 18.5s)
# ObstructiveApnea: 10594.5s to 10609.5s (duration: 15.0s)
# ObstructiveApnea: 10633.0s to 10648.0s (duration: 15.0s)
# ObstructiveApnea: 10665.5s to 10684.0s (duration: 18.5s)
# ObstructiveApnea: 10702.5s to 10719.5s (duration: 17.0s)
# Hypopnea: 10764.0s to 10777.0s (duration: 13.0s)
# ObstructiveApnea: 10802.5s to 10815.0s (duration: 12.5s)
# ObstructiveApnea: 10877.0s to 10892.0s (duration: 15.0s)
# ObstructiveApnea: 10926.5s to 10940.0s (duration: 13.5s)
# ObstructiveApnea: 10959.0s to 10981.5s (duration: 22.5s)
# ObstructiveApnea: 11017.0s to 11032.5s (duration: 15.5s)
# ObstructiveApnea: 11056.0s to 11078.5s (duration: 22.5s)
# ObstructiveApnea: 11093.5s to 11114.5s (duration: 21.0s)
# ObstructiveApnea: 11128.5s to 11142.0s (duration: 13.5s)
# ObstructiveApnea: 11158.0s to 11180.0s (duration: 22.0s)
# ObstructiveApnea: 11214.5s to 11234.5s (duration: 20.0s)
# ObstructiveApnea: 11251.5s to 11268.5s (duration: 17.0s)
# ObstructiveApnea: 11294.0s to 11311.5s (duration: 17.5s)
# Hypopnea: 11337.0s to 11363.5s (duration: 26.5s)
# ObstructiveApnea: 11388.5s to 11406.0s (duration: 17.5s)
# Hypopnea: 11421.0s to 11443.0s (duration: 22.0s)
# ObstructiveApnea: 11457.0s to 11482.5s (duration: 25.5s)
# ObstructiveApnea: 11503.5s to 11522.0s (duration: 18.5s)
# ObstructiveApnea: 11542.5s to 11565.5s (duration: 23.0s)
# ObstructiveApnea: 11598.0s to 11611.5s (duration: 13.5s)
# ObstructiveApnea: 11626.0s to 11643.5s (duration: 17.5s)
# ObstructiveApnea: 11677.5s to 11692.0s (duration: 14.5s)
# ObstructiveApnea: 11711.0s to 11735.5s (duration: 24.5s)
# ObstructiveApnea: 11757.5s to 11773.5s (duration: 16.0s)
# ObstructiveApnea: 11813.0s to 11825.5s (duration: 12.5s)
# ObstructiveApnea: 11858.0s to 11871.5s (duration: 13.5s)
# ObstructiveApnea: 11898.0s to 11917.0s (duration: 19.0s)
# ObstructiveApnea: 11940.5s to 11957.5s (duration: 17.0s)
# ObstructiveApnea: 11974.0s to 11991.0s (duration: 17.0s)
# ObstructiveApnea: 12016.5s to 12039.0s (duration: 22.5s)
# ObstructiveApnea: 12060.5s to 12088.0s (duration: 27.5s)
# ObstructiveApnea: 12106.0s to 12124.0s (duration: 18.0s)
# ObstructiveApnea: 12145.0s to 12158.5s (duration: 13.5s)
# ObstructiveApnea: 12166.0s to 12177.0s (duration: 11.0s)
# ObstructiveApnea: 12195.5s to 12217.5s (duration: 22.0s)
# ObstructiveApnea: 12237.0s to 12250.5s (duration: 13.5s)
# Hypopnea: 12291.0s to 12302.0s (duration: 11.0s)
# ObstructiveApnea: 14077.5s to 14104.5s (duration: 27.0s)
# MixedApnea: 14117.0s to 14152.5s (duration: 35.5s)
# MixedApnea: 14163.5s to 14204.0s (duration: 40.5s)
# MixedApnea: 14218.0s to 14255.5s (duration: 37.5s)
# MixedApnea: 14269.5s to 14305.0s (duration: 35.5s)
# MixedApnea: 14321.5s to 14357.0s (duration: 35.5s)
# MixedApnea: 14368.0s to 14407.5s (duration: 39.5s)
# MixedApnea: 14421.5s to 14443.0s (duration: 21.5s)
# MixedApnea: 14454.5s to 14496.5s (duration: 42.0s)
# ObstructiveApnea: 14512.0s to 14546.0s (duration: 34.0s)
# ObstructiveApnea: 14561.0s to 14599.5s (duration: 38.5s)
# MixedApnea: 14618.0s to 14657.0s (duration: 39.0s)
#    📋 patient_03: Found 362 apnea events
#    🎧 patient_03: Processing EDF 1/5 - 00001217-100507[001].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001217-100507[001].edf: 239 WAV files created
#    🎧 patient_03: Processing EDF 2/5 - 00001217-100507[002].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001217-100507[002].edf: 239 WAV files created
#    🎧 patient_03: Processing EDF 3/5 - 00001217-100507[003].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001217-100507[003].edf: 239 WAV files created
#    🎧 patient_03: Processing EDF 4/5 - 00001217-100507[004].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001217-100507[004].edf: 239 WAV files created
#    🎧 patient_03: Processing EDF 5/5 - 00001217-100507[005].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 5.1 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001217-100507[005].edf: 19 WAV files created
# ✅ patient_03: 975 total WAV files extracted
# 🎯 Progress: patient_03 completed - 975 WAV files
# ----------------------------------------
# 🎵 Starting audio extraction for patient_04...
#    📁 patient_04: Found 5 EDF and 1 RML files
# Hypopnea: 483.5s to 496.5s (duration: 13.0s)
# Hypopnea: 525.0s to 542.0s (duration: 17.0s)
# ObstructiveApnea: 692.5s to 704.5s (duration: 12.0s)
# Hypopnea: 725.5s to 737.0s (duration: 11.5s)
# Hypopnea: 794.5s to 811.5s (duration: 17.0s)
# Hypopnea: 828.5s to 840.5s (duration: 12.0s)
# ObstructiveApnea: 858.0s to 871.5s (duration: 13.5s)
# ObstructiveApnea: 972.0s to 984.5s (duration: 12.5s)
# ObstructiveApnea: 1034.0s to 1050.0s (duration: 16.0s)
# ObstructiveApnea: 1070.5s to 1087.5s (duration: 17.0s)
# ObstructiveApnea: 1127.5s to 1151.0s (duration: 23.5s)
# ObstructiveApnea: 1187.0s to 1226.0s (duration: 39.0s)
# Hypopnea: 2635.5s to 2650.5s (duration: 15.0s)
# Hypopnea: 2700.0s to 2713.0s (duration: 13.0s)
# Hypopnea: 2866.5s to 2880.0s (duration: 13.5s)
# Hypopnea: 2898.5s to 2911.0s (duration: 12.5s)
# Hypopnea: 2952.5s to 2968.5s (duration: 16.0s)
# Hypopnea: 3017.5s to 3033.5s (duration: 16.0s)
# Hypopnea: 3074.5s to 3091.5s (duration: 17.0s)
# Hypopnea: 3119.5s to 3161.0s (duration: 41.5s)
# ObstructiveApnea: 3183.5s to 3219.0s (duration: 35.5s)
# ObstructiveApnea: 3271.5s to 3292.0s (duration: 20.5s)
# ObstructiveApnea: 3327.0s to 3343.5s (duration: 16.5s)
# ObstructiveApnea: 3358.0s to 3371.5s (duration: 13.5s)
# ObstructiveApnea: 3398.5s to 3434.0s (duration: 35.5s)
# ObstructiveApnea: 3463.5s to 3479.5s (duration: 16.0s)
# ObstructiveApnea: 3499.5s to 3520.0s (duration: 20.5s)
# ObstructiveApnea: 3569.0s to 3602.5s (duration: 33.5s)
# ObstructiveApnea: 3655.0s to 3678.0s (duration: 23.0s)
# ...
# ObstructiveApnea: 1884.0s to 1906.5s (duration: 22.5s)
# ObstructiveApnea: 1941.0s to 1951.0s (duration: 10.0s)
# ObstructiveApnea: 1972.5s to 1985.5s (duration: 13.0s)
# ObstructiveApnea: 2007.5s to 2023.5s (duration: 16.0s)
# ObstructiveApnea: 2038.0s to 2060.5s (duration: 22.5s)
# ObstructiveApnea: 2082.0s to 2102.5s (duration: 20.5s)
# ObstructiveApnea: 2119.5s to 2143.5s (duration: 24.0s)
# ObstructiveApnea: 2157.5s to 2177.0s (duration: 19.5s)
# ObstructiveApnea: 2194.0s to 2218.0s (duration: 24.0s)
# Hypopnea: 2241.0s to 2254.0s (duration: 13.0s)
# ObstructiveApnea: 2265.0s to 2276.5s (duration: 11.5s)
# ObstructiveApnea: 2299.0s to 2310.5s (duration: 11.5s)
# ObstructiveApnea: 2324.0s to 2339.5s (duration: 15.5s)
# ObstructiveApnea: 2356.5s to 2381.0s (duration: 24.5s)
# Hypopnea: 2451.5s to 2463.5s (duration: 12.0s)
# ObstructiveApnea: 2486.5s to 2496.5s (duration: 10.0s)
# ObstructiveApnea: 2514.0s to 2526.5s (duration: 12.5s)
# ObstructiveApnea: 2548.0s to 2558.0s (duration: 10.0s)
# ObstructiveApnea: 2569.0s to 2579.0s (duration: 10.0s)
# ObstructiveApnea: 2593.5s to 2608.5s (duration: 15.0s)
# ObstructiveApnea: 2631.0s to 2642.0s (duration: 11.0s)
# ObstructiveApnea: 2655.0s to 2668.5s (duration: 13.5s)
# ObstructiveApnea: 2682.0s to 2693.5s (duration: 11.5s)
# ObstructiveApnea: 2707.0s to 2725.5s (duration: 18.5s)
# Hypopnea: 2958.0s to 2970.0s (duration: 12.0s)
# Hypopnea: 3005.5s to 3018.5s (duration: 13.0s)
# Hypopnea: 3036.5s to 3049.5s (duration: 13.0s)
# ObstructiveApnea: 3116.0s to 3129.5s (duration: 13.5s)
# ObstructiveApnea: 3151.5s to 3166.0s (duration: 14.5s)
# ObstructiveApnea: 3180.5s to 3197.0s (duration: 16.5s)
# ObstructiveApnea: 3221.0s to 3232.5s (duration: 11.5s)
# ObstructiveApnea: 5265.5s to 5277.5s (duration: 12.0s)
# ObstructiveApnea: 5289.0s to 5305.5s (duration: 16.5s)
# ObstructiveApnea: 5324.5s to 5339.5s (duration: 15.0s)
# Hypopnea: 5355.5s to 5367.5s (duration: 12.0s)
# ObstructiveApnea: 5419.5s to 5431.0s (duration: 11.5s)
# ObstructiveApnea: 5446.0s to 5457.0s (duration: 11.0s)
# ObstructiveApnea: 5471.0s to 5481.5s (duration: 10.5s)
# ObstructiveApnea: 5496.5s to 5511.0s (duration: 14.5s)
# ObstructiveApnea: 5549.0s to 5567.0s (duration: 18.0s)
# ObstructiveApnea: 5587.5s to 5601.0s (duration: 13.5s)
# ObstructiveApnea: 5643.5s to 5658.5s (duration: 15.0s)
# ObstructiveApnea: 5690.5s to 5703.5s (duration: 13.0s)
# ObstructiveApnea: 5714.5s to 5724.5s (duration: 10.0s)
# ObstructiveApnea: 5741.0s to 5754.0s (duration: 13.0s)
# ObstructiveApnea: 5770.0s to 5781.5s (duration: 11.5s)
# ObstructiveApnea: 5794.5s to 5809.5s (duration: 15.0s)
# ObstructiveApnea: 5836.5s to 5856.5s (duration: 20.0s)
# ObstructiveApnea: 5880.5s to 5899.0s (duration: 18.5s)
# ObstructiveApnea: 5915.5s to 5928.0s (duration: 12.5s)
# Hypopnea: 5935.5s to 5948.5s (duration: 13.0s)
# Hypopnea: 5968.0s to 5988.0s (duration: 20.0s)
# Hypopnea: 6101.0s to 6114.0s (duration: 13.0s)
# ObstructiveApnea: 6127.0s to 6142.0s (duration: 15.0s)
# ObstructiveApnea: 6166.5s to 6176.5s (duration: 10.0s)
# ObstructiveApnea: 6198.5s to 6214.5s (duration: 16.0s)
# ObstructiveApnea: 6237.0s to 6247.5s (duration: 10.5s)
# ObstructiveApnea: 6309.5s to 6322.5s (duration: 13.0s)
# ObstructiveApnea: 6340.5s to 6351.5s (duration: 11.0s)
# Hypopnea: 6370.0s to 6392.5s (duration: 22.5s)
# ObstructiveApnea: 6416.0s to 6428.5s (duration: 12.5s)
# ObstructiveApnea: 6467.5s to 6486.5s (duration: 19.0s)
# ObstructiveApnea: 6501.5s to 6513.5s (duration: 12.0s)
# ObstructiveApnea: 6532.5s to 6552.0s (duration: 19.5s)
# ObstructiveApnea: 6572.5s to 6585.0s (duration: 12.5s)
# ObstructiveApnea: 6597.0s to 6608.5s (duration: 11.5s)
# Hypopnea: 6630.5s to 6644.0s (duration: 13.5s)
# Hypopnea: 6667.0s to 6679.0s (duration: 12.0s)
# ObstructiveApnea: 6698.0s to 6717.0s (duration: 19.0s)
# ObstructiveApnea: 6734.0s to 6751.0s (duration: 17.0s)
# ObstructiveApnea: 6777.0s to 6794.0s (duration: 17.0s)
# ObstructiveApnea: 6807.5s to 6830.0s (duration: 22.5s)
# ObstructiveApnea: 6857.0s to 6869.5s (duration: 12.5s)
# ObstructiveApnea: 6962.0s to 6974.5s (duration: 12.5s)
# ObstructiveApnea: 7003.5s to 7018.5s (duration: 15.0s)
# ObstructiveApnea: 8935.5s to 8960.0s (duration: 24.5s)
# ObstructiveApnea: 8993.0s to 9015.0s (duration: 22.0s)
# ObstructiveApnea: 9034.5s to 9053.5s (duration: 19.0s)
# Hypopnea: 9102.5s to 9113.0s (duration: 10.5s)
# ObstructiveApnea: 9128.0s to 9139.0s (duration: 11.0s)
# ObstructiveApnea: 9152.0s to 9163.0s (duration: 11.0s)
# Hypopnea: 9198.0s to 9209.0s (duration: 11.0s)
# Hypopnea: 9227.0s to 9242.5s (duration: 15.5s)
# Hypopnea: 9254.0s to 9265.0s (duration: 11.0s)
# Hypopnea: 9278.0s to 9288.5s (duration: 10.5s)
# Hypopnea: 9345.0s to 9365.5s (duration: 20.5s)
# Hypopnea: 9441.0s to 9456.5s (duration: 15.5s)
# ObstructiveApnea: 9487.5s to 9500.0s (duration: 12.5s)
# ObstructiveApnea: 9607.0s to 9621.0s (duration: 14.0s)
# Hypopnea: 9658.5s to 9670.5s (duration: 12.0s)
# ObstructiveApnea: 9687.0s to 9699.0s (duration: 12.0s)
# Hypopnea: 9806.5s to 9817.5s (duration: 11.0s)
# ObstructiveApnea: 10210.5s to 10221.5s (duration: 11.0s)
# ObstructiveApnea: 10279.0s to 10297.0s (duration: 18.0s)
# ObstructiveApnea: 10319.0s to 10330.5s (duration: 11.5s)
# Hypopnea: 10357.0s to 10369.0s (duration: 12.0s)
# ObstructiveApnea: 10384.5s to 10395.5s (duration: 11.0s)
# Hypopnea: 10440.0s to 10451.5s (duration: 11.5s)
# ObstructiveApnea: 10522.5s to 10533.5s (duration: 11.0s)
# ObstructiveApnea: 10539.0s to 10554.0s (duration: 15.0s)
# ObstructiveApnea: 10575.0s to 10594.0s (duration: 19.0s)
# ObstructiveApnea: 10613.0s to 10623.5s (duration: 10.5s)
# ObstructiveApnea: 10638.0s to 10648.5s (duration: 10.5s)
# Hypopnea: 10671.5s to 10685.0s (duration: 13.5s)
# Hypopnea: 10697.0s to 10709.0s (duration: 12.0s)
# Hypopnea: 10725.0s to 10740.5s (duration: 15.5s)
# ObstructiveApnea: 10934.5s to 10946.5s (duration: 12.0s)
# ObstructiveApnea: 10982.5s to 10997.5s (duration: 15.0s)
# ObstructiveApnea: 11011.5s to 11024.5s (duration: 13.0s)
# ObstructiveApnea: 11057.0s to 11074.5s (duration: 17.5s)
# ObstructiveApnea: 11103.5s to 11126.0s (duration: 22.5s)
# ObstructiveApnea: 11154.0s to 11178.5s (duration: 24.5s)
# ObstructiveApnea: 11197.0s to 11214.5s (duration: 17.5s)
# ObstructiveApnea: 11241.0s to 11253.5s (duration: 12.5s)
# ObstructiveApnea: 11272.5s to 11286.5s (duration: 14.0s)
# ObstructiveApnea: 11322.0s to 11345.5s (duration: 23.5s)
# ObstructiveApnea: 11365.5s to 11384.5s (duration: 19.0s)
# ObstructiveApnea: 11401.0s to 11419.0s (duration: 18.0s)
# ObstructiveApnea: 11435.0s to 11456.0s (duration: 21.0s)
# ObstructiveApnea: 11475.5s to 11499.0s (duration: 23.5s)
# ObstructiveApnea: 11603.5s to 11614.0s (duration: 10.5s)
# ObstructiveApnea: 11923.5s to 11935.0s (duration: 11.5s)
# ObstructiveApnea: 12047.5s to 12059.0s (duration: 11.5s)
# ObstructiveApnea: 12078.5s to 12090.0s (duration: 11.5s)
# ObstructiveApnea: 12125.0s to 12137.0s (duration: 12.0s)
# ObstructiveApnea: 12170.0s to 12182.0s (duration: 12.0s)
# ObstructiveApnea: 12209.0s to 12222.5s (duration: 13.5s)
# ObstructiveApnea: 12239.0s to 12249.5s (duration: 10.5s)
# ObstructiveApnea: 12272.0s to 12290.0s (duration: 18.0s)
# ObstructiveApnea: 12309.5s to 12330.0s (duration: 20.5s)
# ObstructiveApnea: 12353.0s to 12376.0s (duration: 23.0s)
# ObstructiveApnea: 12398.5s to 12415.0s (duration: 16.5s)
# ObstructiveApnea: 12462.5s to 12479.0s (duration: 16.5s)
# ObstructiveApnea: 12501.0s to 12520.5s (duration: 19.5s)
# ObstructiveApnea: 12540.0s to 12559.0s (duration: 19.0s)
# Hypopnea: 12583.0s to 12594.5s (duration: 11.5s)
# ObstructiveApnea: 12615.0s to 12628.5s (duration: 13.5s)
# ObstructiveApnea: 12644.5s to 12663.0s (duration: 18.5s)
# ObstructiveApnea: 12680.0s to 12699.5s (duration: 19.5s)
# Hypopnea: 12739.5s to 12749.5s (duration: 10.0s)
# ObstructiveApnea: 12783.0s to 12796.5s (duration: 13.5s)
# ObstructiveApnea: 13643.0s to 13655.5s (duration: 12.5s)
# ObstructiveApnea: 13790.5s to 13801.0s (duration: 10.5s)
# Hypopnea: 13816.5s to 13828.5s (duration: 12.0s)
# Hypopnea: 13843.0s to 13853.0s (duration: 10.0s)
# Hypopnea: 13882.5s to 13895.5s (duration: 13.0s)
# Hypopnea: 13917.5s to 13929.0s (duration: 11.5s)
# Hypopnea: 13945.5s to 13956.5s (duration: 11.0s)
# Hypopnea: 13974.0s to 13986.5s (duration: 12.5s)
# Hypopnea: 14007.5s to 14018.0s (duration: 10.5s)
# ObstructiveApnea: 14054.0s to 14064.0s (duration: 10.0s)
# ObstructiveApnea: 14092.5s to 14105.5s (duration: 13.0s)
# Hypopnea: 14124.5s to 14135.0s (duration: 10.5s)
# Hypopnea: 14237.0s to 14249.5s (duration: 12.5s)
# ObstructiveApnea: 14270.5s to 14282.0s (duration: 11.5s)
# ObstructiveApnea: 14301.0s to 14319.5s (duration: 18.5s)
# Hypopnea: 14341.0s to 14351.5s (duration: 10.5s)
# ObstructiveApnea: 14370.5s to 14386.5s (duration: 16.0s)
# ObstructiveApnea: 14410.5s to 14428.5s (duration: 18.0s)
# ObstructiveApnea: 14447.5s to 14461.5s (duration: 14.0s)
# Hypopnea: 14483.0s to 14494.5s (duration: 11.5s)
# ObstructiveApnea: 14516.0s to 14531.5s (duration: 15.5s)
#    📋 patient_10: Found 271 apnea events
#    🎧 patient_10: Processing EDF 1/5 - 00001295-100507[001].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001295-100507[001].edf: 239 WAV files created
#    🎧 patient_10: Processing EDF 2/5 - 00001295-100507[002].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001295-100507[002].edf: 239 WAV files created
#    🎧 patient_10: Processing EDF 3/5 - 00001295-100507[003].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001295-100507[003].edf: 239 WAV files created
#    🎧 patient_10: Processing EDF 4/5 - 00001295-100507[004].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 60.0 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001295-100507[004].edf: 239 WAV files created
#    🎧 patient_10: Processing EDF 5/5 - 00001295-100507[005].edf
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#       ⏱️  Duration: 2.5 min, SR: 48000 Hz → 16000 Hz
#       ✅ 00001295-100507[005].edf: 9 WAV files created
# ✅ patient_10: 965 total WAV files extracted
# 🎯 Progress: patient_10 completed - 965 WAV files
# ----------------------------------------
#
# ============================================================
# 🏁 AUDIO EXTRACTION COMPLETE!
# ⏱️  Total time: 2432.7 seconds (40.5 minutes)
# 🎵 Total WAV files: 10,972
#
# 📋 AUDIO EXTRACTION STATISTICS:
# 📄 Metadata saved: F:/Solo All In One Docs/Scidb Sleep Data/processed\audio_metadata.csv
# 📊 Total files: 10,972
# 👥 Patients: 10
# 🚨 Apnea files: 6,396 (58.3%)
# 😴 Normal files: 4,576 (41.7%)
#
# 👤 PER-PATIENT WAV FILES:
#    patient_01: 1168 files, 540 apnea (46.2%)
#    patient_02: 1571 files, 499 apnea (31.8%)
#    patient_03: 975 files, 902 apnea (92.5%)
#    patient_04: 1126 files, 646 apnea (57.4%)
#    patient_05: 981 files, 626 apnea (63.8%)
#    patient_06: 989 files, 569 apnea (57.5%)
#    patient_07: 908 files, 732 apnea (80.6%)
#    patient_08: 999 files, 933 apnea (93.4%)
#    patient_09: 1290 files, 331 apnea (25.7%)
#    patient_10: 965 files, 618 apnea (64.0%)
#
# 🎉 SUCCESS! Clean audio extracted and ready for denoising pipeline.
#
# Time finished: 2025-07-30 02:05:32

# %%
# Cell 5: Load Trained Model and Validate Feature Extraction
print("🤖 LOADING TRAINED MODEL FOR BASELINE VALIDATION")
print(f"{'='*60}")

# Load the trained Random Forest model
try:
    model_data = joblib.load(MODEL_PATH)
    
    if isinstance(model_data, dict):
        model = model_data['model']
        feature_columns = model_data.get('feature_columns', None)
        print(f"✅ Model loaded from: {MODEL_PATH}")
        print(f"📊 Model type: {type(model).__name__}")
        if feature_columns:
            print(f"🎯 Expected features: {len(feature_columns)}")
    else:
        # Fallback if model is saved directly
        model = model_data
        feature_columns = None
        print(f"✅ Model loaded (direct): {MODEL_PATH}")
        print(f"📊 Model type: {type(model).__name__}")
        
except Exception as e:
    print(f"❌ Failed to load model: {e}")
    print(f"🔍 Available model files:")
    model_dir = os.path.dirname(MODEL_PATH)
    if os.path.exists(model_dir):
        model_files = [f for f in os.listdir(model_dir) if f.endswith('.pkl')]
        for f in model_files:
            print(f"   - {f}")
    model = None

# Test feature extraction on a sample WAV file
if all_audio_metadata and len(all_audio_metadata) > 0:
    print(f"\n🧪 TESTING FEATURE EXTRACTION ON SAMPLE AUDIO")
    
    # Get first WAV file for testing
    sample_metadata = all_audio_metadata[0]
    sample_wav_path = sample_metadata['wav_path']
    print(f"📁 Sample file: {os.path.basename(sample_wav_path)}")
    
    try:
        # Load audio and extract features
        audio_data, sr = librosa.load(sample_wav_path, sr=TARGET_SAMPLE_RATE)
        print(f"🎵 Audio loaded: {len(audio_data)} samples at {sr} Hz")
        print(f"⏱️  Duration: {len(audio_data)/sr:.1f} seconds")
        
        # Extract features
        features = extract_comprehensive_features(audio_data, sr)
        
        if features:
            print(f"✅ Features extracted: {len(features)} features")
            print(f"🎯 Feature names match training: {'clean_' in list(features.keys())[0]}")
            
            # Display sample features
            print(f"\n📋 SAMPLE FEATURES:")
            for i, (name, value) in enumerate(list(features.items())[:5]):
                print(f"   {name}: {value:.6f}")
            print(f"   ... and {len(features)-5} more features")
            
            # Test model prediction if model is loaded
            if model is not None:
                print(f"\n🔮 TESTING MODEL PREDICTION")
                
                # Convert features to DataFrame
                feature_df = pd.DataFrame([features])
                
                # Ensure feature order matches training if available
                if feature_columns:
                    missing_features = set(feature_columns) - set(feature_df.columns)
                    extra_features = set(feature_df.columns) - set(feature_columns)
                    
                    if missing_features:
                        print(f"⚠️  Missing features: {missing_features}")
                    if extra_features:
                        print(f"⚠️  Extra features: {extra_features}")
                    
                    # Reorder columns to match training
                    feature_df = feature_df.reindex(columns=feature_columns, fill_value=0)
                
                try:
                    # Make prediction
                    prediction = model.predict(feature_df)[0]
                    prediction_proba = model.predict_proba(feature_df)[0]
                    
                    actual_label = sample_metadata['apnea_label']
                    
                    print(f"🎯 Actual label: {actual_label} ({'Apnea' if actual_label else 'Normal'})")
                    print(f"🤖 Predicted: {prediction} ({'Apnea' if prediction else 'Normal'})")
                    print(f"📊 Probability: Normal={prediction_proba[0]:.3f}, Apnea={prediction_proba[1]:.3f}")
                    print(f"✅ Prediction {'correct' if prediction == actual_label else 'incorrect'}")
                    
                except Exception as e:
                    print(f"❌ Model prediction failed: {e}")
            
        else:
            print(f"❌ Feature extraction failed")
            
    except Exception as e:
        print(f"❌ Audio loading/processing failed: {e}")

print(f"\n✅ Feature extraction validation complete")
# Out:
# 🤖 LOADING TRAINED MODEL FOR BASELINE VALIDATION
# ============================================================
# ✅ Model loaded (direct): ../models/sleep_apnea_model.pkl
# 📊 Model type: RandomForestClassifier
#
# 🧪 TESTING FEATURE EXTRACTION ON SAMPLE AUDIO
# 📁 Sample file: patient_01_00001206-100507[001]_frame_000000.wav
# 🎵 Audio loaded: 480000 samples at 16000 Hz
# ⏱️  Duration: 30.0 seconds
# ✅ Features extracted: 27 features
# 🎯 Feature names match training: True
#
# 📋 SAMPLE FEATURES:
#    clean_rms: 0.004864
#    clean_zcr: 0.020327
#    clean_centroid: 1072.004802
#    clean_bandwidth: 1889.160558
#    clean_rolloff: 2834.621535
#    ... and 22 more features
#
# 🔮 TESTING MODEL PREDICTION
# 🎯 Actual label: 0 (Normal)
# 🤖 Predicted: 1 (Apnea)
# 📊 Probability: Normal=0.457, Apnea=0.543
# ✅ Prediction incorrect
#
# ✅ Feature extraction validation complete

# %%
# Cell 6: Establish Clean Audio Baseline Performance
print("📊 ESTABLISHING CLEAN AUDIO BASELINE PERFORMANCE")
print(f"{'='*60}")

if model is not None and all_audio_metadata:
    print(f"🧪 Testing model on {len(all_audio_metadata)} extracted audio files...")
    
    # Extract features from all audio files
    all_features = []
    all_labels = []
    processed_count = 0
    failed_count = 0
    
    print(f"\n🔄 Processing audio files for baseline evaluation...")
    
    for i, metadata in enumerate(all_audio_metadata):
        try:
            # Load audio
            audio_data, sr = librosa.load(metadata['wav_path'], sr=TARGET_SAMPLE_RATE)
            
            # Extract features
            features = extract_comprehensive_features(audio_data, sr)
            
            if features:
                all_features.append(features)
                all_labels.append(metadata['apnea_label'])
                processed_count += 1
            else:
                failed_count += 1
                
        except Exception as e:
            failed_count += 1
            if failed_count <= 5:  # Show first 5 errors
                print(f"   ⚠️  Error processing {os.path.basename(metadata['wav_path'])}: {e}")
        
        # Progress update
        if (i + 1) % 50 == 0:
            print(f"   🔄 Processed {i + 1}/{len(all_audio_metadata)} files...")
    
    print(f"\n📊 Feature extraction complete:")
    print(f"   ✅ Successful: {processed_count}")
    print(f"   ❌ Failed: {failed_count}")
    
    if processed_count > 0:
        # Convert to DataFrame
        features_df = pd.DataFrame(all_features)
        labels = np.array(all_labels)
        
        # Ensure feature order matches training
        if feature_columns:
            features_df = features_df.reindex(columns=feature_columns, fill_value=0)
        
        print(f"\n🤖 Making predictions on clean audio...")
        
        try:
            # Make predictions
            predictions = model.predict(features_df)
            prediction_probas = model.predict_proba(features_df)
            
            # Calculate performance metrics
            f1 = f1_score(labels, predictions)
            
            # Detailed classification report
            print(f"\n📈 CLEAN AUDIO BASELINE PERFORMANCE:")
            print(f"🎯 F1-Score: {f1:.3f}")
            
            print(f"\n📋 Detailed Classification Report:")
            report = classification_report(labels, predictions, 
                                         target_names=['Normal', 'Apnea'], 
                                         output_dict=True)
            
            print(f"   Normal Breathing:")
            print(f"     Precision: {report['Normal']['precision']:.3f}")
            print(f"     Recall: {report['Normal']['recall']:.3f}")
            print(f"     F1-Score: {report['Normal']['f1-score']:.3f}")
            
            print(f"   Sleep Apnea:")
            print(f"     Precision: {report['Apnea']['precision']:.3f}")
            print(f"     Recall (Sensitivity): {report['Apnea']['recall']:.3f}")
            print(f"     F1-Score: {report['Apnea']['f1-score']:.3f}")
            
            print(f"   Overall:")
            print(f"     Accuracy: {report['accuracy']:.3f}")
            print(f"     Macro F1: {report['macro avg']['f1-score']:.3f}")
            print(f"     Weighted F1: {report['weighted avg']['f1-score']:.3f}")
            
            # Confusion matrix
            cm = confusion_matrix(labels, predictions)
            print(f"\n📊 Confusion Matrix:")
            print(f"                 Predicted")
            print(f"Actual    Normal  Apnea")
            print(f"Normal    {cm[0,0]:6d}  {cm[0,1]:5d}")
            print(f"Apnea     {cm[1,0]:6d}  {cm[1,1]:5d}")
            
            # Calculate medical metrics
            tn, fp, fn, tp = cm.ravel()
            sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
            specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
            
            print(f"\n🏥 Medical Metrics:")
            print(f"   Sensitivity (True Positive Rate): {sensitivity:.3f}")
            print(f"   Specificity (True Negative Rate): {specificity:.3f}")
            print(f"   False Positive Rate: {fp/(fp+tn):.3f}")
            print(f"   False Negative Rate: {fn/(fn+tp):.3f}")
            
            # Save baseline results
            baseline_results = {
                'clean_f1_score': f1,
                'clean_sensitivity': sensitivity,
                'clean_specificity': specificity,
                'clean_accuracy': report['accuracy'],
                'total_samples': len(labels),
                'apnea_samples': int(labels.sum()),
                'normal_samples': int(len(labels) - labels.sum()),
                'confusion_matrix': cm.tolist(),
                'classification_report': report
            }
            
            # Save to file
            baseline_path = os.path.join(AUDIO_OUTPUT_DIR, "clean_audio_baseline_results.json")
            import json
            with open(baseline_path, 'w') as f:
                json.dump(baseline_results, f, indent=2)
            
            print(f"\n💾 Baseline results saved: {baseline_path}")
            print(f"\n🎉 CLEAN AUDIO BASELINE ESTABLISHED!")
            print(f"📊 Ready for Phase 2: Noise injection and degradation analysis")
            
        except Exception as e:
            print(f"❌ Model evaluation failed: {e}")
            import traceback
            traceback.print_exc()
    
    else:
        print(f"❌ No features extracted successfully")

else:
    if model is None:
        print(f"⚠️  Skipping baseline evaluation - model not loaded")
    if not all_audio_metadata:
        print(f"⚠️  Skipping baseline evaluation - no audio files extracted")

print(f"\n✅ Phase 1 complete - Ready for noise injection experiments!")
# Out:
# 📊 ESTABLISHING CLEAN AUDIO BASELINE PERFORMANCE
# ============================================================
# 🧪 Testing model on 10972 extracted audio files...
#
# 🔄 Processing audio files for baseline evaluation...
#    🔄 Processed 50/10972 files...
#    🔄 Processed 100/10972 files...
#    🔄 Processed 150/10972 files...
#    🔄 Processed 200/10972 files...
#    🔄 Processed 250/10972 files...
#    🔄 Processed 300/10972 files...
#    🔄 Processed 350/10972 files...
#    🔄 Processed 400/10972 files...
#    🔄 Processed 450/10972 files...
#    🔄 Processed 500/10972 files...
#    🔄 Processed 550/10972 files...
#    🔄 Processed 600/10972 files...
#    🔄 Processed 650/10972 files...
#    🔄 Processed 700/10972 files...
#    🔄 Processed 750/10972 files...
#    🔄 Processed 800/10972 files...
#    🔄 Processed 850/10972 files...
#    🔄 Processed 900/10972 files...
#    🔄 Processed 950/10972 files...
#    🔄 Processed 1000/10972 files...
#    🔄 Processed 1050/10972 files...
#    🔄 Processed 1100/10972 files...
#    🔄 Processed 1150/10972 files...
#    🔄 Processed 1200/10972 files...
#    🔄 Processed 1250/10972 files...
#    🔄 Processed 1300/10972 files...
#    🔄 Processed 1350/10972 files...
#    🔄 Processed 1400/10972 files...
#    🔄 Processed 1450/10972 files...
#    🔄 Processed 1500/10972 files...
#    🔄 Processed 1550/10972 files...
#    🔄 Processed 1600/10972 files...
#    🔄 Processed 9700/10972 files...
#    🔄 Processed 9750/10972 files...
#    🔄 Processed 9800/10972 files...
#    🔄 Processed 9850/10972 files...
#    🔄 Processed 9900/10972 files...
#    🔄 Processed 9950/10972 files...
#    🔄 Processed 10000/10972 files...
#    🔄 Processed 10050/10972 files...
#    🔄 Processed 10100/10972 files...
#    🔄 Processed 10150/10972 files...
#    🔄 Processed 10200/10972 files...
#    🔄 Processed 10250/10972 files...
#    🔄 Processed 10300/10972 files...
#    🔄 Processed 10350/10972 files...
#    🔄 Processed 10400/10972 files...
#    🔄 Processed 10450/10972 files...
#    🔄 Processed 10500/10972 files...
#    🔄 Processed 10550/10972 files...
#    🔄 Processed 10600/10972 files...
#    🔄 Processed 10650/10972 files...
#    🔄 Processed 10700/10972 files...
#    🔄 Processed 10750/10972 files...
#    🔄 Processed 10800/10972 files...
#    🔄 Processed 10850/10972 files...
#    🔄 Processed 10900/10972 files...
#    🔄 Processed 10950/10972 files...
#
# 📊 Feature extraction complete:
#    ✅ Successful: 10972
#    ❌ Failed: 0
#
# 🤖 Making predictions on clean audio...
#
# 📈 CLEAN AUDIO BASELINE PERFORMANCE:
# 🎯 F1-Score: 0.758
#
# 📋 Detailed Classification Report:
#    Normal Breathing:
#      Precision: 0.654
#      Recall: 0.806
#      F1-Score: 0.722
#    Sleep Apnea:
#      Precision: 0.833
#      Recall (Sensitivity): 0.695
#      F1-Score: 0.758
#    Overall:
#      Accuracy: 0.741
#      Macro F1: 0.740
#      Weighted F1: 0.743
#
# 📊 Confusion Matrix:
#                  Predicted
# Actual    Normal  Apnea
# Normal      3687    889
# Apnea       1952   4444
#
# 🏥 Medical Metrics:
#    Sensitivity (True Positive Rate): 0.695
#    Specificity (True Negative Rate): 0.806
#    False Positive Rate: 0.194
#    False Negative Rate: 0.305
#
# 💾 Baseline results saved: F:/Solo All In One Docs/Scidb Sleep Data/processed\clean_audio_baseline_results.json
#
# 🎉 CLEAN AUDIO BASELINE ESTABLISHED!
# 📊 Ready for Phase 2: Noise injection and degradation analysis
#
# ✅ Phase 1 complete - Ready for noise injection experiments!

# %% [markdown]
# ---
#
# # Phase 1 Summary
#
# ## Completed:
# 1. ✅ **EDF to WAV Conversion**: Extracted clean audio from clinical EDF files
# 2. ✅ **Feature Extraction Validation**: Confirmed 27 features match training pipeline
# 3. ✅ **Model Loading**: Successfully loaded trained Random Forest model
# 4. ✅ **Baseline Performance**: Established clean audio performance metrics
# 5. ✅ **Test Set Preparation**: Created standardized WAV files for denoising pipeline
#
# ## Key Outputs:
# - **WAV Files**: Patient audio organized in `{AUDIO_OUTPUT_DIR}/patient_XX_wav/`
# - **Metadata**: `audio_metadata.csv` with file paths and apnea labels
# - **Baseline Results**: `clean_audio_baseline_results.json` with performance metrics
# - **Feature Validation**: Confirmed feature extraction pipeline works correctly
#
# ## Next Steps:
# - **Phase 2**: Noise injection and baseline degradation analysis
# - **Phase 3**: Comprehensive denoising method evaluation
# - **Phase 4**: Multi-criteria analysis and smartphone deployment recommendations
#
# ---
